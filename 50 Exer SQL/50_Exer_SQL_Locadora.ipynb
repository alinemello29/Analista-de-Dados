# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.10/dist-packages (9.1.0)

# %%
import mysql.connector
import pandas as pd

# %%
host = '34.69.233.123'
user = ''
password =''
database = 'locadora'

# %%
# !curl ipecho.net/plain
# Out:
# 35.196.36.83

# %%
def consulta(query, tabela):
  connection = mysql.connector.connect(
      host = host,
      user = user,
      password = password,
      database = database
  )
  cursor = connection.cursor()

  try:
    cursor.execute(query)
    result = cursor.fetchall()
    globals()[tabela] = pd.DataFrame(result, columns=cursor.column_names)
    display(globals()[tabela])
  finally:
    cursor.close()
    connection.close()

# %% [markdown]
# #1 - Selecione todos os dados da tabela cliente

# %%
consulta('''
SELECT * FROM cliente;
''', ''' ''')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C

# %% [markdown]
# #2 - Liste todos os clientes que moram na cidade de "São Paulo".

# %%
consulta('''
SELECT * FROM cliente
WHERE cidade = 'São Paulo';
''', ''' ''')
# Out:
#    codcliente           nome     cidade sexo estado estadocivil
# 0           5  Lúcia Andrade  São Paulo    F     SP           C

# %% [markdown]
# #3 - Liste os estados diferentes presentes na tabela cliente.

# %%
consulta('''
SELECT DISTINCT estado FROM cliente;
''', ''' ''')
# Out:
#   estado
# 0     RJ
# 1     SP

# %% [markdown]
# #4 - Liste todos os clientes ordenados pelo nome em ordem alfabética.

# %%
consulta('''
SELECT * FROM cliente
ORDER BY nome ASC;
''',''' ''')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           4    Fernando Souza         Campinas    M     SP           S
# 3           5     Lúcia Andrade        São Paulo    F     SP           C
# 4           3  Túlio Nascimento  Duque de Caxias    M     RJ           S

# %% [markdown]
# # 5. Encontre todos os clientes que são do sexo feminino e solteiros.

# %%
 consulta('''
SELECT * FROM cliente
WHERE sexo = 'Feminino' AND estadocivil = 'Solteiro';
''', ''' ''')
# Out:
# Empty DataFrame
# Columns: [codcliente, nome, cidade, sexo, estado, estadocivil]
# Index: []

# %% [markdown]
# # 6. Liste todos os clientes cujo nome começa com a letra 'A'.

# %%
consulta('''
SELECT * FROM cliente WHERE nome LIKE 'A%';
''', ''' ''')
# Out:
#    codcliente       nome           cidade sexo estado estadocivil
# 0           1  Ana Silva  Duque de Caxias    F     RJ           C

# %% [markdown]
# # 7. Selecione os 3 primeiros registros da tabela cliente.

# %%
consulta('''
SELECT * FROM cliente LIMIT 3;
''', ''' ''')
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S

# %% [markdown]
# # 8. Liste todos os carros que são da marca 'Ford' ou 'Fiat'.

# %%
consulta('''
SELECT * FROM carro
WHERE modelo IN ('Ford');
''', ''' ''')
# Out:
# Empty DataFrame
# Columns: [codcarro, codmarca, modelo, valor]
# Index: []

# %% [markdown]
# # 9. Encontre todos os carros cujo valor está entre 100 e 150.

# %%
consulta('''
SELECT * FROM carro WHERE valor BETWEEN 100 AND 150;
''', ''' ''')
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         4         4   Polo  150.0
# 3         5         5   Kwid  120.0

# %% [markdown]
# # 10. Conte quantos aluguéis foram realizados.

# %%
consulta('''
SELECT COUNT(*) FROM aluguel;
''', ''' ''')
# Out:
#    COUNT(*)
# 0        10

# %% [markdown]
# # 11. Calcule o valor total de todos os carros disponíveis para aluguel.

# %%
consulta('''
SELECT SUM(valor) FROM carro;
''', 'valor total de todos os carros')
# Out:
#    SUM(valor)
# 0       690.0

# %% [markdown]
# # 12. Calcule o valor médio dos carros.

# %%
consulta('''
SELECT AVG(valor) FROM carro;
''', ''' ''')
# Out:
#    AVG(valor)
# 0       138.0

# %% [markdown]
# # 13. Encontre o menor e o maior valor de aluguel de carros.

# %%
consulta('''
SELECT MIN(valor) AS menor_valor, MAX(valor) AS maior_valor FROM carro;
''', ''' ''')
# Out:
#    menor_valor  maior_valor
# 0        100.0        170.0

# %% [markdown]
# # 14. Agrupe os clientes por estado e conte quantos clientes existem em cada estado.

# %%
consulta('''
SELECT estado, COUNT(*) FROM cliente GROUP BY estado;
''', ''' ''')
# Out:
#   estado  COUNT(*)
# 0     RJ         3
# 1     SP         2

# %% [markdown]
# # 15. Agrupe os aluguéis por cliente e filtre apenas aqueles que fizeram mais de 2 aluguéis.

# %%
consulta('''
SELECT codcliente, COUNT(*)
FROM aluguel
GROUP BY codcliente
HAVING COUNT(*) > 2;
''', ''' ''')
# Out:
#    codcliente  COUNT(*)
# 0           1         3
# 1           2         3

# %% [markdown]
# # 16. Liste todos os aluguéis, mostrando o nome do cliente e o modelo do carro alugado.

# %%
consulta('''
SELECT c.nome, car.modelo
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente
JOIN carro car ON a.codcarro = car.codcarro;
''', ''' ''')
# Out:
#                nome modelo
# 0  Túlio Nascimento   Argo
# 1     Bruna Pereira     Ka
# 2     Bruna Pereira     Ka
# 3     Bruna Pereira   Onix
# 4         Ana Silva   Polo
# 5         Ana Silva   Polo
# 6         Ana Silva     Ka
# 7     Lúcia Andrade   Argo
# 8     Lúcia Andrade   Argo
# 9  Túlio Nascimento     Ka

# %% [markdown]
# # 17. Liste todos os carros e, se houver, as informações sobre os aluguéis realizados desses carros.

# %%
consulta('''
SELECT car.*, a.data_aluguel
FROM carro car
LEFT JOIN aluguel a ON car.codcarro = a.codcarro;
''', ''' ''')
# Out:
#     codcarro  codmarca modelo  valor data_aluguel
# 0          1         1     Ka  100.0   2023-04-02
# 1          1         1     Ka  100.0   2023-04-03
# 2          1         1     Ka  100.0   2023-04-15
# 3          1         1     Ka  100.0   2023-04-25
# 4          2         2   Argo  150.0   2023-04-01
# 5          2         2   Argo  150.0   2023-04-19
# 6          2         2   Argo  150.0   2023-04-21
# 7          3         3   Onix  170.0   2023-04-04
# 8          4         4   Polo  150.0   2023-04-05
# 9          4         4   Polo  150.0   2023-04-13
# 10         5         5   Kwid  120.0         None

# %% [markdown]
# # 18. Liste todos os aluguéis e as informações sobre os carros alugados, mesmo que o carro não esteja mais no banco de dados.

# %%
consulta('''
SELECT a.*, car.modelo
FROM aluguel a
LEFT JOIN carro car ON a.codcarro = car.codcarro;
''', ''' ''')
# Out:
#    codaluguel  codcliente  codcarro data_aluguel modelo
# 0           1           3         2   2023-04-01   Argo
# 1           2           2         1   2023-04-02     Ka
# 2           3           2         1   2023-04-03     Ka
# 3           4           2         3   2023-04-04   Onix
# 4           5           1         4   2023-04-05   Polo
# 5           6           1         4   2023-04-13   Polo
# 6           7           1         1   2023-04-15     Ka
# 7           8           5         2   2023-04-19   Argo
# 8           9           5         2   2023-04-21   Argo
# 9          10           3         1   2023-04-25     Ka

# %% [markdown]
# # 19. Liste todos os clientes e os carros que alugaram, incluindo clientes que não alugaram e carros que não foram alugados.

# %%
consulta('''
SELECT c.nome, car.modelo
FROM cliente c
LEFT JOIN aluguel a ON c.codcliente = a.codcliente
LEFT JOIN carro car ON a.codcarro = car.codcarro;
''', ''' ''')
# Out:
#                 nome modelo
# 0          Ana Silva   Polo
# 1          Ana Silva   Polo
# 2          Ana Silva     Ka
# 3      Bruna Pereira     Ka
# 4      Bruna Pereira     Ka
# 5      Bruna Pereira   Onix
# 6   Túlio Nascimento   Argo
# 7   Túlio Nascimento     Ka
# 8     Fernando Souza   None
# 9      Lúcia Andrade   Argo
# 10     Lúcia Andrade   Argo

# %% [markdown]
# # 20. Combine os resultados de duas consultas: uma que lista clientes solteiros e outra que lista clientes casados.

# %%
consulta('''
SELECT * FROM cliente WHERE estado = 'Solteiro'
UNION
SELECT * FROM cliente WHERE estado = 'Casado';
''', ''' ''')
# Out:
# Empty DataFrame
# Columns: [codcliente, nome, cidade, sexo, estado, estadocivil]
# Index: []

# %% [markdown]
# # 21. Encontre os clientes que alugaram o carro com modelo 'Onix'.

# %%
consulta('''
SELECT c.*
FROM cliente c
JOIN aluguel a ON c.codcliente = a.codcliente
JOIN carro car ON a.codcarro = car.codcarro
WHERE car.modelo = 'Onix';
''', ''' ''')
# Out:
#    codcliente           nome   cidade sexo estado estadocivil
# 0           2  Bruna Pereira  Niterói    F     RJ           C

# %% [markdown]
# # 22. Liste os modelos de carros e o número de vezes que cada um foi alugado.

# %%
consulta('''
SELECT car.modelo, COUNT(a.codaluguel) AS quantidade
FROM carro car
LEFT JOIN aluguel a ON car.codcarro = a.codcarro
GROUP BY car.modelo;
''' ''', ''')
# Out:
#   modelo  quantidade
# 0     Ka           4
# 1   Argo           3
# 2   Onix           1
# 3   Polo           2
# 4   Kwid           0

# %% [markdown]
# # 23. Liste o nome dos clientes e o número de aluguéis que cada um fez.

# %%
consulta('''
SELECT c.nome, COUNT(a.codaluguel) AS quantidade
FROM cliente c
LEFT JOIN aluguel a ON c.codcliente = a.codcliente
GROUP BY c.nome;
''', ''' ''')
# Out:
#                nome  quantidade
# 0         Ana Silva           3
# 1     Bruna Pereira           3
# 2  Túlio Nascimento           2
# 3    Fernando Souza           0
# 4     Lúcia Andrade           2

# %% [markdown]
# # 24. Crie uma consulta que retorne o nome dos clientes e uma coluna adicional chamada status_civil que classifica os clientes como "Solteiro" ou "Casado".

# %%
consulta('''
SELECT nome, estadocivil AS status_civil
FROM cliente;
''', ''' ''')
# Out:
#                nome status_civil
# 0         Ana Silva            C
# 1     Bruna Pereira            C
# 2  Túlio Nascimento            S
# 3    Fernando Souza            S
# 4     Lúcia Andrade            C

# %% [markdown]
# # 25. Liste os nomes dos clientes e as datas em que alugaram carros.

# %%
consulta('''
SELECT c.nome, a.data_aluguel
FROM cliente c
JOIN aluguel a ON c.codcliente = a.codcliente;
''', ''' ''')
# Out:
#                nome data_aluguel
# 0         Ana Silva   2023-04-05
# 1         Ana Silva   2023-04-13
# 2         Ana Silva   2023-04-15
# 3     Bruna Pereira   2023-04-02
# 4     Bruna Pereira   2023-04-03
# 5     Bruna Pereira   2023-04-04
# 6  Túlio Nascimento   2023-04-01
# 7  Túlio Nascimento   2023-04-25
# 8     Lúcia Andrade   2023-04-19
# 9     Lúcia Andrade   2023-04-21

# %% [markdown]
# # 26. Liste todos os modelos de carros e suas respectivas marcas.

# %%
consulta('''
SELECT modelo
marca FROM carro;
''', ''' ''')
# Out:
#   marca
# 0    Ka
# 1  Argo
# 2  Onix
# 3  Polo
# 4  Kwid

# %% [markdown]
# # 27. Liste todos os aluguéis e os nomes dos clientes que os realizaram.

# %%
consulta('''
SELECT a.*, c.nome
FROM aluguel a
JOIN cliente c ON a.codcliente = c.codcliente;
''', ''' ''')
# Out:
#    codaluguel  codcliente  codcarro data_aluguel              nome
# 0           5           1         4   2023-04-05         Ana Silva
# 1           6           1         4   2023-04-13         Ana Silva
# 2           7           1         1   2023-04-15         Ana Silva
# 3           2           2         1   2023-04-02     Bruna Pereira
# 4           3           2         1   2023-04-03     Bruna Pereira
# 5           4           2         3   2023-04-04     Bruna Pereira
# 6           1           3         2   2023-04-01  Túlio Nascimento
# 7          10           3         1   2023-04-25  Túlio Nascimento
# 8           8           5         2   2023-04-19     Lúcia Andrade
# 9           9           5         2   2023-04-21     Lúcia Andrade

# %% [markdown]
# # 28. Encontre o nome dos clientes e os modelos de carros que alugaram.

# %%
consulta('''
SELECT c.nome, car.modelo
FROM cliente c
JOIN aluguel a ON c.codcliente = a.codcliente
JOIN carro car ON a.codcarro = car.codcarro;
''', ''' ''')
# Out:
#                nome modelo
# 0  Túlio Nascimento   Argo
# 1     Bruna Pereira     Ka
# 2     Bruna Pereira     Ka
# 3     Bruna Pereira   Onix
# 4         Ana Silva   Polo
# 5         Ana Silva   Polo
# 6         Ana Silva     Ka
# 7     Lúcia Andrade   Argo
# 8     Lúcia Andrade   Argo
# 9  Túlio Nascimento     Ka

# %% [markdown]
# # 29. Liste todos os carros e, se houver, mostre as datas em que foram alugados.

# %%
consulta('''
SELECT c.codcarro, c.codmarca, c.modelo, c.valor, a.data_aluguel
FROM carro c
LEFT JOIN aluguel a ON c.codcarro = a.codcarro;
''', ''' ''')
# Out:
#    codcarro  codmarca modelo  valor data_aluguel
# 0         1         1     Ka  100.0   2023-04-25
# 1         1         1     Ka  100.0   2023-04-15
# 2         1         1     Ka  100.0   2023-04-03
# 3         1         1     Ka  100.0   2023-04-02
# 4         2         2   Argo  150.0   2024-11-19
# 5         2         2   Argo  150.0   2023-04-01
# 6         3         3   Onix  200.0   2023-04-04
# 7         4         4   Polo  150.0   2023-04-13
# 8         4         4   Polo  150.0   2023-04-05

# %% [markdown]
# # 30. Encontre os clientes que moram na mesma cidade e estado e que alugaram carros.

# %%
consulta('''
SELECT DISTINCT c1.nome AS cliente_1,
                c2.nome AS cliente_2,
                c1.estado,
                c1.cidade

FROM cliente c1
JOIN cliente c2 ON c1.cidade = c2.cidade AND c1.estado = c2.estado AND c1.codcliente <> c2.codcliente
JOIN aluguel a1 ON c1.codcliente = a1.codcliente
JOIN aluguel a2 ON c2.codcliente = a2.codcliente;
''',''' ''')
# Out:
#           cliente_1         cliente_2 estado           cidade
# 0  Túlio Nascimento        Aline Melo     RJ  Duque de Caxias
# 1        Aline Melo  Túlio Nascimento     RJ  Duque de Caxias

# %% [markdown]
# # 31. Liste os nomes dos clientes e os carros que eles alugaram, incluindo os clientes que não alugaram nenhum carro.

# %%
consulta('''
SELECT cliente.nome, carro.modelo
FROM cliente
LEFT JOIN aluguel
ON cliente.codcliente = aluguel.codcliente
LEFT JOIN carro
ON aluguel.codcarro = carro.codcarro;
''', ''' ''')
# Out:
#                nome modelo
# 0        Aline Melo   Polo
# 1        Aline Melo   Polo
# 2        Aline Melo     Ka
# 3        Aline Melo   Argo
# 4     Bruna Pereira     Ka
# 5     Bruna Pereira     Ka
# 6     Bruna Pereira   Onix
# 7  Túlio Nascimento   Argo
# 8  Túlio Nascimento     Ka
# 9        João Silva   None

# %% [markdown]
# # 32. Liste todas as marcas e, se houver, os modelos de carros associados.

# %%
consulta('''
SELECT codmarca, modelo FROM carro;
''', ''' ''')
# Out:
#    codmarca modelo
# 0         1     Ka
# 1         2   Argo
# 2         3   Onix
# 3         4   Polo

# %% [markdown]
# # 33. Encontre todos os aluguéis e o estado civil dos clientes que alugaram os carros.

# %%
consulta('''
SELECT aluguel.codaluguel,
       cliente.nome,
       cliente.estadocivil,
       aluguel.data_aluguel
FROM aluguel
JOIN cliente
ON aluguel.codcliente = cliente.codcliente
ORDER BY aluguel.codaluguel;
''', ''' ''')
# Out:
#    codaluguel              nome estadocivil data_aluguel
# 0           1  Túlio Nascimento           S   2023-04-01
# 1           2     Bruna Pereira           C   2023-04-02
# 2           3     Bruna Pereira           C   2023-04-03
# 3           4     Bruna Pereira           C   2023-04-04
# 4           5        Aline Melo           C   2023-04-05
# 5           6        Aline Melo           C   2023-04-13
# 6           7        Aline Melo           C   2023-04-15
# 7          10  Túlio Nascimento           S   2023-04-25
# 8          11        Aline Melo           C   2024-11-19

# %% [markdown]
# # 34. Liste os clientes e as cidades em que moram para aqueles que alugaram carros.

# %%
consulta('''
SELECT DISTINCT cliente.nome,
       cliente.cidade
FROM cliente
JOIN aluguel
ON aluguel.codcliente = cliente.codcliente;
''', ''' ''')
# Out:
#                nome           cidade
# 0        Aline Melo  Duque de Caxias
# 1     Bruna Pereira          Niterói
# 2  Túlio Nascimento  Duque de Caxias

# %% [markdown]
# # 35. Liste os clientes que alugaram carros e os modelos de carros que eles alugaram, incluindo a marca do carro.

# %%
consulta('''
SELECT DISTINCT cliente.nome,
       carro.modelo,
       marca.marca
FROM aluguel
JOIN cliente ON aluguel.codcliente = cliente.codcliente
JOIN carro ON aluguel.codcarro = carro.codcarro
JOIN marca ON carro.codmarca = marca.codmarca
ORDER BY cliente.nome;
''', ''' ''')
# Out:
#                nome modelo       marca
# 0        Aline Melo     Ka        Ford
# 1        Aline Melo   Argo        Fiat
# 2        Aline Melo   Polo  Volkswagen
# 3     Bruna Pereira     Ka        Ford
# 4     Bruna Pereira   Onix   Chevrolet
# 5  Túlio Nascimento     Ka        Ford
# 6  Túlio Nascimento   Argo        Fiat

# %% [markdown]
# # 36. Encontre todos os aluguéis realizados em uma cidade específica e liste os nomes dos clientes e os modelos de carros alugados.

# %%
consulta('''
SELECT cliente.nome,
       carro.modelo,
       cliente.cidade
FROM aluguel
JOIN cliente ON aluguel.codcliente = cliente.codcliente
JOIN carro ON aluguel.codcarro = carro.codcarro
WHERE cliente.cidade = 'Niterói';
''', ''' ''')
# Out:
#             nome modelo   cidade
# 0  Bruna Pereira     Ka  Niterói
# 1  Bruna Pereira     Ka  Niterói
# 2  Bruna Pereira   Onix  Niterói

# %% [markdown]
# # 37. Liste os modelos de carros e a quantidade de vezes que foram alugados.

# %%
consulta('''
SELECT carro.modelo,
       COUNT(aluguel.codcarro) AS qtde
FROM carro
JOIN aluguel ON carro.codcarro = aluguel.codcarro
GROUP BY carro.modelo
ORDER BY COUNT(aluguel.codcarro) DESC;
''', ''' ''')
# Out:
#   modelo  qtde
# 0     Ka     4
# 1   Argo     2
# 2   Polo     2
# 3   Onix     1

# %% [markdown]
# # 38. Encontre os clientes que alugaram mais de um carro.

# %%
consulta('''
SELECT cliente.nome,
       COUNT(aluguel.codcarro) AS qtde_de_alugueis
FROM aluguel
JOIN cliente ON aluguel.codcliente = cliente.codcliente
GROUP BY
  cliente.nome
HAVING COUNT(aluguel.codcarro) > 1
ORDER BY COUNT(aluguel.codcarro) DESC;
''', ''' ''')
# Out:
#                nome  qtde_de_alugueis
# 0        Aline Melo                 4
# 1     Bruna Pereira                 3
# 2  Túlio Nascimento                 2

# %% [markdown]
# # 39. Liste os clientes, as datas de aluguel e o valor do carro alugado.

# %%
consulta('''
SELECT cliente.nome,
       aluguel.data_aluguel,
       carro.valor
FROM aluguel
JOIN cliente ON aluguel.codcliente = cliente.codcliente
JOIN carro ON aluguel.codcarro = carro.codcarro;
''', ''' ''')
# Out:
#                nome data_aluguel  valor
# 0  Túlio Nascimento   2023-04-01  150.0
# 1     Bruna Pereira   2023-04-02  100.0
# 2     Bruna Pereira   2023-04-03  100.0
# 3     Bruna Pereira   2023-04-04  200.0
# 4        Aline Melo   2023-04-05  150.0
# 5        Aline Melo   2023-04-13  150.0
# 6        Aline Melo   2023-04-15  100.0
# 7  Túlio Nascimento   2023-04-25  100.0
# 8        Aline Melo   2024-11-19  150.0

# %% [markdown]
# # 40. Liste os modelos de carros que nunca foram alugados.

# %%
consulta('''
SELECT carro.modelo
FROM carro
LEFT JOIN aluguel ON carro.codcarro = aluguel.codcarro
WHERE aluguel.codcarro IS NULL;
''', ''' ''')
# Out:
# Empty DataFrame
# Columns: [modelo]
# Index: []

# %% [markdown]
# # 41. Encontre os clientes que alugaram carros e o total gasto em aluguéis.

# %%
consulta('''
SELECT cliente.nome,
       SUM(valor) AS Valor_total
FROM aluguel
JOIN cliente ON aluguel.codcliente = cliente.codcliente
JOIN carro ON aluguel.codcarro = carro.codcarro
GROUP BY cliente.nome
ORDER BY cliente.nome;
''', ''' ''')
# Out:
#                nome  Valor_total
# 0        Aline Melo        550.0
# 1     Bruna Pereira        400.0
# 2  Túlio Nascimento        250.0

# %% [markdown]
# # 42. Liste as marcas de carros e o número total de aluguéis por marca.

# %%
consulta('''
SELECT marca.marca,
       COUNT(aluguel.codaluguel) QTDE
FROM marca
JOIN carro ON marca.codmarca = carro.codmarca
JOIN aluguel ON carro.codcarro = aluguel.codcarro
GROUP BY
  marca.marca
ORDER BY COUNT(aluguel.codaluguel)  DESC;
''', ''' ''')
# Out:
#         marca  QTDE
# 0        Ford     4
# 1        Fiat     2
# 2  Volkswagen     2
# 3   Chevrolet     1

# %% [markdown]
# # 43. Encontre os clientes que alugaram carros em um determinado mês e ano, listando os modelos de carros e as datas de aluguel.

# %%
consulta('''
SELECT cliente.nome,
       carro.modelo,
       aluguel.data_aluguel
FROM aluguel
JOIN cliente ON aluguel.codcliente = cliente.codcliente
JOIN carro ON aluguel.codcarro = carro.codcarro
WHERE
MONTH(aluguel.data_aluguel) = 4 AND YEAR(aluguel.data_aluguel) = 2023;
''', ''' ''')

# %% [markdown]
# # 44. Liste os clientes que moram em estados diferentes e que alugaram carros, junto com os modelos alugados.

# %%
consulta('''
SELECT DISTINCT cliente.nome,
                cliente.estado,
                carro.modelo
FROM cliente
JOIN aluguel
ON aluguel.codcliente = cliente.codcliente
JOIN carro
ON carro.codcarro = aluguel.codcarro
ORDER BY cliente.estado, cliente.nome;
''', ''' ''')
# Out:
#                nome estado modelo
# 0        Aline Melo     RJ   Polo
# 1        Aline Melo     RJ     Ka
# 2        Aline Melo     RJ   Argo
# 3     Bruna Pereira     RJ     Ka
# 4     Bruna Pereira     RJ   Onix
# 5  Túlio Nascimento     RJ   Argo
# 6  Túlio Nascimento     RJ     Ka

# %% [markdown]
# # 45. Encontre os clientes que alugaram carros, os modelos de carros alugados, as marcas desses carros e as datas de aluguel, ordenando pelos nomes dos clientes.

# %%
consulta('''
SELECT cliente.nome,
       carro.modelo,
       marca.marca,
       aluguel.data_aluguel
FROM aluguel
JOIN cliente ON aluguel.codcliente = cliente.codcliente
JOIN carro ON aluguel.codcarro = carro.codcarro
JOIN marca ON carro.codmarca = marca.codmarca
ORDER BY cliente.nome;
''', ''' ''')
# Out:
#                nome modelo       marca data_aluguel
# 0        Aline Melo   Polo  Volkswagen   2023-04-05
# 1        Aline Melo   Polo  Volkswagen   2023-04-13
# 2        Aline Melo     Ka        Ford   2023-04-15
# 3        Aline Melo   Argo        Fiat   2024-11-19
# 4     Bruna Pereira     Ka        Ford   2023-04-02
# 5     Bruna Pereira     Ka        Ford   2023-04-03
# 6     Bruna Pereira   Onix   Chevrolet   2023-04-04
# 7  Túlio Nascimento   Argo        Fiat   2023-04-01
# 8  Túlio Nascimento     Ka        Ford   2023-04-25

# %% [markdown]
# # 46. Liste os clientes que alugaram carros mais de uma vez e os detalhes dos carros que alugaram.

# %%
consulta('''
SELECT
    cliente.nome AS nome_cliente,
    carro.modelo AS modelo_carro,
    marca.marca AS nome_marca,
    aluguel.data_aluguel
FROM
    aluguel
JOIN cliente ON aluguel.codcliente = cliente.codcliente
JOIN carro ON aluguel.codcarro = carro.codcarro
JOIN marca ON carro.codmarca = marca.codmarca
WHERE
    aluguel.codcliente IN (
        SELECT codcliente
        FROM aluguel
        GROUP BY codcliente
        HAVING COUNT(codaluguel) > 1
    )
ORDER BY
    cliente.nome;
''', ''' ''')
# Out:
#        nome_cliente modelo_carro  nome_marca data_aluguel
# 0        Aline Melo         Polo  Volkswagen   2023-04-05
# 1        Aline Melo         Polo  Volkswagen   2023-04-13
# 2        Aline Melo           Ka        Ford   2023-04-15
# 3        Aline Melo         Argo        Fiat   2024-11-19
# 4     Bruna Pereira           Ka        Ford   2023-04-02
# 5     Bruna Pereira           Ka        Ford   2023-04-03
# 6     Bruna Pereira         Onix   Chevrolet   2023-04-04
# 7  Túlio Nascimento         Argo        Fiat   2023-04-01
# 8  Túlio Nascimento           Ka        Ford   2023-04-25

# %% [markdown]
# # 47. Encontre os modelos de carros que foram alugados por clientes de cidades específicas e liste as marcas desses carros.

# %%
consulta('''
SELECT cliente.nome,
       cliente.cidade,
       carro.modelo,
       marca.marca
FROM aluguel
JOIN cliente ON aluguel.codcliente = cliente.codcliente
JOIN carro ON aluguel.codcarro = carro.codcarro
JOIN marca ON marca.codmarca = carro.codmarca
WHERE cliente.cidade = 'Niterói'
OR cliente.cidade = 'São Paulo';
''', ''' ''')
# Out:
#             nome   cidade modelo      marca
# 0  Bruna Pereira  Niterói     Ka       Ford
# 1  Bruna Pereira  Niterói     Ka       Ford
# 2  Bruna Pereira  Niterói   Onix  Chevrolet

# %% [markdown]
# # 48. Liste os clientes que alugaram carros, os modelos e as marcas dos carros, e o total gasto em aluguéis, agrupado por cliente.

# %%
consulta('''
SELECT DISTINCT cliente.nome,
       carro.modelo,
       marca.marca,
       SUM(carro.valor)
FROM aluguel
JOIN cliente ON aluguel.codcliente = cliente.codcliente
JOIN carro ON aluguel.codcarro = carro.codcarro
JOIN marca ON carro.codmarca = marca.codmarca
GROUP BY
    cliente.nome,
    carro.modelo,
    marca.marca;
''', ''' ''')
# Out:
#                nome modelo       marca  SUM(carro.valor)
# 0     Bruna Pereira     Ka        Ford             200.0
# 1        Aline Melo     Ka        Ford             100.0
# 2  Túlio Nascimento     Ka        Ford             100.0
# 3  Túlio Nascimento   Argo        Fiat             150.0
# 4        Aline Melo   Argo        Fiat             150.0
# 5     Bruna Pereira   Onix   Chevrolet             200.0
# 6        Aline Melo   Polo  Volkswagen             300.0

# %% [markdown]
# # 49. Encontre os carros que foram alugados nos últimos 30 dias e os clientes que os alugaram.

# %%
consulta('''
SELECT
    cliente.nome AS nome_cliente,
    carro.modelo AS modelo_carro,
    aluguel.data_aluguel
FROM
    aluguel
JOIN cliente ON aluguel.codcliente = cliente.codcliente
JOIN carro ON aluguel.codcarro = carro.codcarro
WHERE
    aluguel.data_aluguel >= DATE_SUB(CURDATE(), INTERVAL 730 DAY);;
''', ''' ''')
# Out:
#        nome_cliente modelo_carro data_aluguel
# 0  Túlio Nascimento         Argo   2023-04-01
# 1     Bruna Pereira           Ka   2023-04-02
# 2     Bruna Pereira           Ka   2023-04-03
# 3     Bruna Pereira         Onix   2023-04-04
# 4        Aline Melo         Polo   2023-04-05
# 5        Aline Melo         Polo   2023-04-13
# 6        Aline Melo           Ka   2023-04-15
# 7  Túlio Nascimento           Ka   2023-04-25
# 8        Aline Melo         Argo   2024-11-19

# %% [markdown]
# # 50. Liste os clientes, os carros que alugaram, as marcas desses carros, e o valor total gasto em aluguéis, filtrando por um intervalo de datas específico.

# %%
consulta('''
SELECT
    cliente.nome AS nome_cliente,
    carro.modelo AS modelo_carro,
    marca.marca AS nome_marca,
    SUM(carro.valor) AS total_gasto
FROM
    aluguel
JOIN cliente ON aluguel.codcliente = cliente.codcliente
JOIN carro ON aluguel.codcarro = carro.codcarro
JOIN marca ON carro.codmarca = marca.codmarca
WHERE
    aluguel.data_aluguel BETWEEN '2022-10-19' AND '2024-11-18'
GROUP BY
    cliente.codcliente, cliente.nome, carro.modelo, marca.marca;
''', ''' ''')
# Out:
#        nome_cliente modelo_carro  nome_marca  total_gasto
# 0  Túlio Nascimento         Argo        Fiat        150.0
# 1     Bruna Pereira           Ka        Ford        200.0
# 2     Bruna Pereira         Onix   Chevrolet        200.0
# 3        Aline Melo         Polo  Volkswagen        300.0
# 4        Aline Melo           Ka        Ford        100.0
# 5  Túlio Nascimento           Ka        Ford        100.0

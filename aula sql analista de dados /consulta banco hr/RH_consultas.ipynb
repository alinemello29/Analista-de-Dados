# %%
# !pip install mysql-connector-python
# Out:
# Requirement already satisfied: mysql-connector-python in /usr/local/lib/python3.10/dist-packages (9.1.0)

# %%
import mysql.connector
import pandas as pd

# %%
host = '34.69.233.123'
user = ''
password =''
database = 'rh'

# %%
# !curl ipecho.net/plain
# Out:
# 35.224.3.88

# %%
def consulta(query, tabela):
  connection = mysql.connector.connect(
      host = host,
      user = user,
      password = password,
      database = database
  )
  cursor = connection.cursor()

  try:
    cursor.execute(query)
    result = cursor.fetchall()
    globals()[tabela] = pd.DataFrame(result, columns=cursor.column_names)
    display(globals()[tabela])
  finally:
    cursor.close()
    connection.close()

# %%
consulta('''
show tables;
''','tabelas')
# Out:
#   Tables_in_rh
# 0  funcionario

# %% [markdown]
# #SELECT

# %%
'''
Esta cláusula serve para selecionar um ou mais atributos (colunas)
de uma ou mais tabelas

Exemplo: selecionar os registros para o atributo nome da tabela
funcionarios
'''
consulta('''
SELECT nome
FROM funcionario;
''','nomes_funcionario')
# Out:
#        nome
# 0     Lucas
# 1       Ana
# 2     Luiza
# 3  Fernando
# 4    Sandra
# 5   Douglas
# 6   Eduardo
# 7     Ester
# 8     Pedro
# 9     Maria

# %%
'''
Exemplo: selecionar os registros para o atributo matricula e o atributo nome
da tabela funcionarios
'''
consulta('''
SELECT matricula, nome
FROM funcionario;
''','ids_nomes_funcionario')
# Out:
#     matricula      nome
# 0           0      nome
# 1           1     Lucas
# 2           2       Ana
# 3           3     Luiza
# 4           4  Fernando
# 5           5    Sandra
# 6           6   Douglas
# 7           7   Eduardo
# 8           8     Ester
# 9           9     Pedro
# 10         10     Maria

# %%
'''
Exemplo: selecionar os registros para todos os atributos da tabela
funcionarios
'''
consulta('''
SELECT *
FROM funcionario;
''','funcionario')
# Out:
#     matricula      nome     cidade estado    pais  idade  departamento  \
# 0           0      nome     cidade     es    pais      0  departamento
# 1           1     Lucas    Atibaia     SP  Brasil     35       Compras
# 2           2       Ana  São Paulo     SP  Brasil     29        Vendas
# 3           3     Luiza     Santos     SP  Brasil     38      Finanças
# 4           4  Fernando    Atibaia     SP  Brasil     36     Marketing
# 5           5    Sandra    Atibaia     SP  Brasil     28      Produção
# 6           6   Douglas   Bragança     SP  Brasil     29      Finanças
# 7           7   Eduardo    Extrema     MG  Brasil     30     Marketing
# 8           8     Ester    Itapeva     MG  Brasil     29       Compras
# 9           9     Pedro    Extrema     MG  Brasil     30     Marketing
# 10         10     Maria    Extrema     MG  Brasil     40      Produção
#
#           cargo   salario  escolaridade nota
# 0         cargo      0.00  escolaridade  0.0
# 1       Gerente  25000.00      Superior  8.0
# 2   Coordenador  12000.00      Superior  6.0
# 3       Gerente  28000.00           MBA  9.0
# 4       Diretor  40000.00      Mestrado  7.0
# 5      Analista  23000.00      Superior  5.0
# 6      Analista  11000.00      Superior  9.0
# 7       Gerente  12000.00           MBA  4.0
# 8      Analista  10000.00      Superior  2.0
# 9      Analista  13000.00      Superior  1.0
# 10     Analista  12000.00           MBA  7.0

# %% [markdown]
# #WHERE

# %%
'''
Faça uma consulta que retorne todos os nomes e cidades de clientes
que moram em Atibaia
'''
consulta('''
SELECT nome, cidade
FROM funcionario
WHERE cidade = 'Atibaia';
''','cidades')
# Out:
#        nome   cidade
# 0     Lucas  Atibaia
# 1  Fernando  Atibaia
# 2    Sandra  Atibaia

# %%
'''
Faça uma consulta que retorne todos os nomes de funcionarios cuja nota
seja maior que 6
'''
consulta('''
SELECT nome
FROM funcionario
WHERE nota > 6;
''','aprovados')
# Out:
#        nome
# 0     Lucas
# 1     Luiza
# 2  Fernando
# 3   Douglas
# 4     Maria

# %% [markdown]
# #DISTINCT

# %%
'''
Quais são os estados (UFs) diferentes estão representados em
Nossa tabela Clientes
'''
consulta('''
SELECT DISTINCT estado
FROM funcionario
''','ufs')
# Out:
#   estado
# 0     SP
# 1     MG

# %% [markdown]
# #LIMIT

# %%
'''
Imagine que você deseja fazer uma consulta que retorne apenas
os cinco primeiros nomes de funcionarios
'''
consulta('''
SELECT nome
FROM funcionario
LIMIT 5;
''','primeiros_funcionario')
# Out:
#        nome
# 0     Lucas
# 1       Ana
# 2     Luiza
# 3  Fernando
# 4    Sandra

# %% [markdown]
# #Consultas com BOOLEANOS (E | OU | NÃO)

# %%
'''
Faça uma consultas que retorne todos os funcionarios que moram no estado de SP
e possuem salário acima de R$ 30.000,00
'''
consulta('''
SELECT nome, estado
FROM funcionario
WHERE estado = 'SP'
AND
salario > 30000;
''','burgueses')
# Out:
#        nome estado
# 0  Fernando     SP

# %%
'''
Faça uma consulta que retorne todos os nomes e endereços de funcionarios
que moram em SP ou MG
'''
consulta('''
SELECT nome, estado
From funcionario
WHERE estado = 'SP'
OR
estado = 'MG'
;
''','cafe_leite')
# Out:
#        nome estado
# 0     Lucas     SP
# 1       Ana     SP
# 2     Luiza     SP
# 3  Fernando     SP
# 4    Sandra     SP
# 5   Douglas     SP
# 6   Eduardo     MG
# 7     Ester     MG
# 8     Pedro     MG
# 9     Maria     MG

# %%
'''
Faça uma consulta que retorne todos os clientes que não sejam de SP
'''
consulta('''
SELECT nome, estado
FROM funcionario
WHERE NOT estado = 'SP';
''','no_sp')
# Out:
#       nome estado
# 0  Eduardo     MG
# 1    Ester     MG
# 2    Pedro     MG
# 3    Maria     MG

# %% [markdown]
# #Funções de Agregação (MIN, MAX, COUNT, ROUND, AVG, SUM)

# %% [markdown]
# #COUNT

# %%
'''
Faça uma consulta que retorne a contagem de funcionarios
'''
consulta('''
SELECT count(matricula) as Contagem
FROM funcionario;
''','contagem')
# Out:
#    Contagem
# 0        10

# %% [markdown]
# #AVG

# %%
'''
Faça uma consulta que retorne a média dos sallários
dos funcionários
'''
consulta('''
SELECT AVG(salario) salario_medio
FROM funcionario;
''','salario_medio')
# Out:
#   salario_medio
# 0  18600.000000

# %% [markdown]
# #MAX

# %%
'''
Faça uma consulta que retorne o maior salário
'''
consulta('''
SELECT MAX(salario) salario_maximo
FROM funcionario;
''','maior_salario')
# Out:
#   salario_maximo
# 0       40000.00

# %% [markdown]
# #MIN

# %%
'''
Faça uma consulta que retorne o menor salário
'''
consulta('''
SELECT MIN(salario) salario_minimo
FROM funcionario;
''','menor_salario')
# Out:
#   salario_minimo
# 0       10000.00

# %% [markdown]
# #ROUND

# %%
'''
Faça uma consulta que retorne a média dos salaérios
 arredondada com duas casas decimais
'''
consulta('''
SELECT ROUND(AVG(salario),2) salario_medio_2
FROM funcionario;
''','salario_medio')
# Out:
#   salario_medio_2
# 0        18600.00

# %% [markdown]
# #SUM

# %%
'''
Faça uma consulta que retorne a soma de todas os salarios
da tabela funcionarios
'''
consulta('''
SELECT SUM(salario) as salario_total
FROM funcionario;
''','salario_total')
# Out:
#   salario_total
# 0     186000.00

# %% [markdown]
# #GROUP BY

# %%
'''
Faça uma consulta que retorne o salário médio agrupado por
Departamento
'''
consulta('''
SELECT departamento, AVG(salario) salario_medio
FROM funcionario
GROUP BY departamento;
''','salario_departamento')
# Out:
#   departamento salario_medio
# 0      Compras  17500.000000
# 1       Vendas  12000.000000
# 2     Finanças  19500.000000
# 3    Marketing  21666.666667
# 4     Produção  17500.000000

# %%
'''
Faça uma consulta que retorne a nota média por cargo
'''
consulta('''
SELECT cargo, AVG(nota) nota_media
FROM funcionario
GROUP BY cargo;
''', 'nota_por_cargo')
# Out:
#          cargo nota_media
# 0      Gerente    7.00000
# 1  Coordenador    6.00000
# 2      Diretor    7.00000
# 3     Analista    4.80000

# %%
'''
Faça uma consulta que retorne o maior salário por cidade
'''
consulta('''
SELECT cidade, MAX(salario) as maior_salario
FROM funcionario
GROUP BY cidade;
''','maior_salario')
# Out:
#       cidade maior_salario
# 0    Atibaia      40000.00
# 1  São Paulo      12000.00
# 2     Santos      28000.00
# 3   Bragança      11000.00
# 4    Extrema      13000.00
# 5    Itapeva      10000.00

# %%
'''
Faça uma consulta que retorne o salário médio por departamento e cargo
'''
consulta('''
SELECT departamento, cargo, AVG(salario) salario_medio
FROM funcionario
GROUP BY departamento, cargo;
''','salario2')
# Out:
#   departamento        cargo salario_medio
# 0      Compras      Gerente  25000.000000
# 1       Vendas  Coordenador  12000.000000
# 2     Finanças      Gerente  28000.000000
# 3    Marketing      Diretor  40000.000000
# 4     Produção     Analista  17500.000000
# 5     Finanças     Analista  11000.000000
# 6    Marketing      Gerente  12000.000000
# 7      Compras     Analista  10000.000000
# 8    Marketing     Analista  13000.000000

# %% [markdown]
# #HAVING

# %%
'''
Imagine que você deseja filtrar apenas os salários médios por cidades acima de
R$ 20.000,00
'''
consulta('''
SELECT cidade, AVG(salario) as salario_medio
FROM funcionario
GROUP BY cidade
HAVING AVG(salario) > 20000;
''','medio_salario')
# Out:
#     cidade salario_medio
# 0  Atibaia  29333.333333
# 1   Santos  28000.000000

# %%
'''
Faça uma consulta que retorne todos os nomes de funcionarios cuja nota
seja maior que 6
'''
'''
A Cláusula HAVING substitui o WHERE quando os dados estão agrupados e agregados
'''
consulta('''
SELECT departamento, cargo, AVG(nota) nota_media
FROM funcionario
GROUP BY departamento, cargo
HAVING AVG(nota) > 6;
''','aprovados')
# Out:
#   departamento     cargo nota_media
# 0      Compras   Gerente    8.00000
# 1     Finanças   Gerente    9.00000
# 2    Marketing   Diretor    7.00000
# 3     Finanças  Analista    9.00000

# %% [markdown]
# #UNION

# %%
'''
Imagine que você deseja criar uma consulta que retorne nome e cidade
apenas dos funcionários de Atibaia
'''
consulta('''
SELECT nome, cidade
FROM funcionario
WHERE cidade = 'Atibaia';
''','atibaia')
# Out:
#        nome   cidade
# 0     Lucas  Atibaia
# 1  Fernando  Atibaia
# 2    Sandra  Atibaia

# %%
'''
Imagine que você deseja criar uma consulta que retorne nome e cidade
apenas dos funcionários de Extrema
'''
consulta('''
SELECT nome, cidade
FROM funcionario
WHERE cidade = 'Extrema';
''','extrema')
# Out:
#       nome   cidade
# 0  Eduardo  Extrema
# 1    Pedro  Extrema
# 2    Maria  Extrema

# %%
'''
Imagine que você deseja criar as duas consultas anteriores unidas em
uma única consulta sem usar o operador OR
'''
consulta('''
SELECT nome, cidade
FROM funcionario
WHERE cidade = 'Atibaia'
UNION
SELECT nome, cidade
FROM funcionario
WHERE cidade = 'Extrema';
''','atibaia_extrema')
# Out:
#        nome   cidade
# 0     Lucas  Atibaia
# 1  Fernando  Atibaia
# 2    Sandra  Atibaia
# 3   Eduardo  Extrema
# 4     Pedro  Extrema
# 5     Maria  Extrema

# %% [markdown]
# #IN

# %%
'''
Imagine que você deseja fazer uma consulta que retorne os nomes e salários dos
funcionários de matrícula 1, 4 e 8
'''
consulta('''
SELECT nome, salario
FROM funcionario
WHERE matricula IN (1,4,8);
''','burguesia')
# Out:
#        nome   salario
# 0     Lucas  25000.00
# 1  Fernando  40000.00
# 2     Ester  10000.00

# %% [markdown]
# #BETWEEN

# %%
'''
Imagine que você deseja selecionar matricula e nome dos
funcionários cujas matriculas esteja entre 3 e 8
'''
consulta('''
SELECT matricula, nome
FROM funcionario
WHERE matricula BETWEEN 3 AND 8;
''','galera')
# Out:
#    matricula      nome
# 0          3     Luiza
# 1          4  Fernando
# 2          5    Sandra
# 3          6   Douglas
# 4          7   Eduardo
# 5          8     Ester

# %%
'''
Imagine que você deseja fazer uma consulta que retorne todos os nomes
de funcionários ordenados de forma crescente
'''
consulta('''
SELECT nome
FROM funcionario
ORDER BY nome ASC;
''','TOC')
# Out:
#        nome
# 0       Ana
# 1   Douglas
# 2   Eduardo
# 3     Ester
# 4  Fernando
# 5     Lucas
# 6     Luiza
# 7     Maria
# 8     Pedro
# 9    Sandra

# %%
'''
Imagine que você deseja fazer uma consulta que retorne todos os nomes
de funcionários ordenados de forma decrescente
'''
consulta('''
SELECT nome
FROM funcionario
ORDER BY nome DESC;
''','TOC2')
# Out:
#        nome
# 0    Sandra
# 1     Pedro
# 2     Maria
# 3     Luiza
# 4     Lucas
# 5  Fernando
# 6     Ester
# 7   Eduardo
# 8   Douglas
# 9       Ana

# %%
consulta('''
SELECT DEFAULT_COLLATION_NAME FROM information_schema.SCHEMATA WHERE SCHEMA_NAME = 'rh';
''',
'''
collation
''')
# Out:
#   DEFAULT_COLLATION_NAME
# 0     utf8mb4_0900_ai_ci

# %%
'''
faça uma consulta que retorne todos os registros  com escolaridade superior
'''
consulta('''
SELECT escolaridade
FROM funcionario
WHERE escolaridade = 'superior'
''',
'''
escola
''')
# Out:
#   escolaridade
# 0     Superior
# 1     Superior
# 2     Superior
# 3     Superior
# 4     Superior
# 5     Superior

# %%
'''
faça uma consulta que retorne todos os registros  com escolaridade superior
'''
consulta('''
SELECT escolaridade
FROM funcionario
WHERE BINARY escolaridade = 'superior'
''',
'''
escola
''')
# Out:
# Empty DataFrame
# Columns: [escolaridade]
# Index: []

# %% [markdown]
# # LIKE

# %%
'''
Faça uma consulta de todos os nomes de funcionários que começa a letra D
'''
consulta('''
SELECT nome
FROM funcionario
WHERE nome LIKE 'D%';
''',
'''
nomes_legais
''')
# Out:
#       nome
# 0  Douglas

# %%
'''
Faça uma consulta que retorne todos os nomes que terminam com letra S
'''

consulta('''
SELECT nome
FROM funcionario
WHERE BINARY nome LIKE '%s';
''',
'''
nomes_legais2
''')
# Out:
#       nome
# 0    Lucas
# 1  Douglas

# %%
'''
Faça uma ocnsulta de todos os nomes que contenham
OU
'''
consulta('''
SELECT nome
FROM funcionario
WHERE BINARY nome LIKE '%ou%';
''',
'''
nomes_legais3
''')
# Out:
#       nome
# 0  Douglas

# %% [markdown]
# #TRIM

# %%
'''
Faça uma consulta que retorne os nomes da cidades removendo
espaços do começo para final da string se houver
'''
consulta('''
SELECT TRIM(cidade)  as no_space
FROM funcionario;
''',''' Cidades''')
# Out:
#     no_space
# 0    Atibaia
# 1  São Paulo
# 2     Santos
# 3    Atibaia
# 4    Atibaia
# 5   Bragança
# 6    Extrema
# 7    Itapeva
# 8    Extrema
# 9    Extrema

# %% [markdown]
# #REPLACE

# %%
'''
faça uma consulta que retorne os nomes onde a letra o seja substituida pro
dois oo
'''

consulta('''
SELECT REPLACE(nome, 'o', 'oo') as name_fun
FROM funcionario;
''',''' ''')
# Out:
#     name_fun
# 0      Lucas
# 1        Ana
# 2      Luiza
# 3  Fernandoo
# 4     Sandra
# 5   Doouglas
# 6   Eduardoo
# 7      Ester
# 8     Pedroo
# 9      Maria

# %%
'''
Faça uma consulta que retorne todos os nomes em caixa alta
'''
consulta('''
SELECT UPPER(nome) mai
FROM funcionario;
''', '''mai''')
# Out:
#         mai
# 0     LUCAS
# 1       ANA
# 2     LUIZA
# 3  FERNANDO
# 4    SANDRA
# 5   DOUGLAS
# 6   EDUARDO
# 7     ESTER
# 8     PEDRO
# 9     MARIA

# %%
'''
Faça uma consulta que retorne todos os nomes em caixa baixa
'''
consulta('''
SELECT LOWER(nome) min
FROM funcionario;
''', '''min''')
# Out:
#         min
# 0     lucas
# 1       ana
# 2     luiza
# 3  fernando
# 4    sandra
# 5   douglas
# 6   eduardo
# 7     ester
# 8     pedro
# 9     maria

# %% [markdown]
# #CONCAT e CAST

# %%
'''
faça uam consulta que retorne a matricula ocm texto e concatenada
com o prefixo funcionario
'''
consulta('''
SELECT CONCAT('Funcionário - ', CAST(matricula AS CHAR)) matricula_texto
FROM funcionario;
''','''abc''')
# Out:
#     matricula_texto
# 0   Funcionário - 1
# 1   Funcionário - 2
# 2   Funcionário - 3
# 3   Funcionário - 4
# 4   Funcionário - 5
# 5   Funcionário - 6
# 6   Funcionário - 7
# 7   Funcionário - 8
# 8   Funcionário - 9
# 9  Funcionário - 10

# %% [markdown]
# #CASE - WHEN

# %%
'''
faça uma ocnsulta que retorne nome, notas e uma coluna
adiocional com aprovados para notas maiores que 6 e
provvados para os demais
'''

consulta('''
SELECT nome, nota,
  CASE WHEN nota > 6 THEN 'Aprovado'
  ELSE 'Reprovado' END
  fROM funcionario;
''', '''status''')
# Out:
#        nome nota CASE WHEN nota > 6 THEN 'Aprovado'\n  ELSE 'Reprovado' END
# 0     Lucas  8.0                                           Aprovado
# 1       Ana  6.0                                          Reprovado
# 2     Luiza  9.0                                           Aprovado
# 3  Fernando  7.0                                           Aprovado
# 4    Sandra  5.0                                          Reprovado
# 5   Douglas  9.0                                           Aprovado
# 6   Eduardo  4.0                                          Reprovado
# 7     Ester  2.0                                          Reprovado
# 8     Pedro  1.0                                          Reprovado
# 9     Maria  7.0                                           Aprovado

# %%
'''
Esse exemplos deixa mais organizado a tabela, tabela de cima foi a que prof fez
essa aqui foi um aluno que falou
'''

consulta('''
SELECT nome, nota,
  (CASE WHEN nota > 6 THEN 'Aprovado'
  ELSE 'Reprovado' END) status
  fROM funcionario;
''', '''status''')
# Out:
#        nome nota     status
# 0     Lucas  8.0   Aprovado
# 1       Ana  6.0  Reprovado
# 2     Luiza  9.0   Aprovado
# 3  Fernando  7.0   Aprovado
# 4    Sandra  5.0  Reprovado
# 5   Douglas  9.0   Aprovado
# 6   Eduardo  4.0  Reprovado
# 7     Ester  2.0  Reprovado
# 8     Pedro  1.0  Reprovado
# 9     Maria  7.0   Aprovado

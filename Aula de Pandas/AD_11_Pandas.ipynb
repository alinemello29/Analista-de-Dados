# %%
import pandas as pd

# %%
# Criando uma base para trannsformá-la em DF
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']

# %%
# Transformar as listas do bloco anterior em um DF
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura', 'peso', 'sexo'])
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
# Exibindo as informações do DF
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6 entries, 0 to 5
# Data columns (total 5 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   nome    6 non-null      object
#  1   idade   6 non-null      int64
#  2   altura  6 non-null      float64
#  3   peso    6 non-null      int64
#  4   sexo    6 non-null      object
# dtypes: float64(1), int64(2), object(2)
# memory usage: 368.0+ bytes

# %%
medidas = df.describe()
medidas.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 8 entries, count to max
# Data columns (total 3 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   idade   8 non-null      float64
#  1   altura  8 non-null      float64
#  2   massa   8 non-null      float64
# dtypes: float64(3)
# memory usage: 256.0+ bytes

# %%
display(medidas)
# Out:
#            idade   altura       peso
# count   6.000000  6.00000   6.000000
# mean   43.333333  1.67500  67.833333
# std    21.266562  0.22731  25.615750
# min     7.000000  1.23000  22.000000
# 25%    38.250000  1.68500  65.000000
# 50%    43.500000  1.74000  69.000000
# 75%    59.250000  1.80250  82.750000
# max    65.000000  1.85000  96.000000

# %%
# Exibindo o número de linhas e colunas (nesta ordem)
df.shape
# Out:
# (6, 5)

# %%
# Exibindo aleatoriamente os dados de uma linha
df.sample(1)
# Out:
#       nome  idade  altura  peso sexo
# 4  Eduardo     42    1.82    96    M

# %%
# Exibindo as primeiras linha do df
df.head(1)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M

# %%
# Exibindo os últimos registros
df.tail(3)
# Out:
#       nome  idade  altura  peso sexo
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
# Exibindo as informações do índice
df.index
# Out:
# RangeIndex(start=0, stop=6, step=1)

# %% [markdown]
# # Fatiamento do DF

# %%
# Exibir as informações de uma linha específica usando seu rótulo
cara_bacana = df.loc[0]
display(cara_bacana)
# Out:
# nome      Douglas
# idade          45
# altura       1.85
# peso           70
# sexo            M
# Name: 0, dtype: object

# %%
# Exibir as informações de uma linha específica usando seu rótulo
objeto = medidas.loc['mean']
display(objeto)
# Out:
# idade     43.333333
# altura     1.675000
# peso      67.833333
# Name: mean, dtype: float64

# %%
type(objeto)
# Out:
# pandas.core.series.Series

# %%
# Transformando uma Series pandas em uma lista Python
lista = list(objeto)
type(lista)
# Out:
# list

# %%
print(lista)
# Out:
# [43.333333333333336, 1.675, 67.83333333333333]

# %%
# Exibindo mais de uma linha pelo rótulo
df.loc[[0,2]]
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 2    Pedro     65    1.75    87    M

# %%
# Exibindo média e desvio padrão do df medidas
medidas.loc[['mean','std']]
# Out:
#           idade   altura       peso
# mean  43.333333  1.67500  67.833333
# std   21.266562  0.22731  25.615750

# %%
# Exibindo informações de uma linha específica polo índice
df.iloc[0]
# Out:
# nome      Douglas
# idade          45
# altura       1.85
# peso           70
# sexo            M
# Name: 0, dtype: object

# %%
# Exibindo informações de uma linha específica polo índice
medidas.iloc[0]
# Out:
# idade     6.0
# altura    6.0
# peso      6.0
# Name: count, dtype: float64

# %%
# Exibindo mais de uma linha pelo índice
df.iloc[[0,2]]
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     45    1.85    70    M
# 2    Pedro     65    1.75    87    M

# %%
# Exibindo mais de uma linha pelo índice
medidas.iloc[[1,2]]
# Out:
#           idade   altura       peso
# mean  43.333333  1.67500  67.833333
# std   21.266562  0.22731  25.615750

# %%
# Exibindo informações de uma coluna pelo rótulo
df.loc[:,'nome']
# Out:
# 0    Douglas
# 1    Daniela
# 2      Pedro
# 3      Maria
# 4    Eduardo
# 5      Ester
# Name: nome, dtype: object

# %%
# Exibindo informações de uma coluna pelo rótulo
medidas.loc[:,'idade']
# Out:
# count     6.000000
# mean     43.333333
# std      21.266562
# min       7.000000
# 25%      38.250000
# 50%      43.500000
# 75%      59.250000
# max      65.000000
# Name: idade, dtype: float64

# %%
# Exibindo dados de mais de uma coluna pelo seu rótulo
df.loc[:,['nome','idade']]
# Out:
#       nome  idade
# 0  Douglas     45
# 1  Daniela      7
# 2    Pedro     65
# 3    Maria     64
# 4  Eduardo     42
# 5    Ester     37

# %%
'''
Imagine que você deseja saber nome e alturas dos elementos
das linhas de rótulo 0, 2 , 4
'''
df.loc[[0,2,4],['nome', 'altura']]
# Out:
#       nome  altura
# 0  Douglas    1.85
# 2    Pedro    1.75
# 4  Eduardo    1.82

# %%
# Exibindo os dados de uma coluna pelo seu índice
df.iloc[:,0]
# Out:
# 0    Douglas
# 1    Daniela
# 2      Pedro
# 3      Maria
# 4    Eduardo
# 5      Ester
# Name: nome, dtype: object

# %%
# Exibindo os dados de uma coluna pelo seu índice
df.iloc[:,[0,2]]
# Out:
#       nome  altura
# 0  Douglas    1.85
# 1  Daniela    1.23
# 2    Pedro    1.75
# 3    Maria    1.67
# 4  Eduardo    1.82
# 5    Ester    1.73

# %%
'''
Imagine que você deseja saber nome e alturas dos elementos
das linhas de índice 0, 2 , 4
'''
df.iloc[[0,2,4],[0,2]]
# Out:
#       nome  altura
# 0  Douglas    1.85
# 2    Pedro    1.75
# 4  Eduardo    1.82

# %%
'''
Exibindo as informações de uma célula pelo rótulo
'''
df.loc[0,'idade']
# Out:
# 45

# %%
'''
Exibindo as informações de uma célula pelo índice
'''
df.iloc[0,1]
# Out:
# 45

# %% [markdown]
# Operações que modificam o DataFrame

# %%
'''
Alterar a idade de Douglas de 45, para 48
'''
df.loc[0,'idade'] = 48

# %%
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     48    1.85    70    M
# 1  Daniela      7    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
'''
Alterar a idade de Daniela de 7 para 10 pelo índice
'''
df.iloc[1,1] = 10
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     48    1.85    70    M
# 1  Daniela     10    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %% [markdown]
# # Renomear colunas

# %%
# Método 1
'''
Renomear as colunas de peso e sexo, por respectivamente massa e genero
'''
df.rename(columns={'peso':'massa','sexo':'genero'},inplace=True)

# %%
# voltando aos nomes originais
df.rename(columns={'massa':'peso','genero':'sexo'},inplace=True)
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     48    1.85    70    M
# 1  Daniela     10    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
# método 02
'''
Renomear as colunas de peso e sexo, por respectivamente massa e genero
'''
df = df.rename(columns={'peso':'massa','sexo':'genero'})
display(df)
# Out:
#       nome  idade  altura  massa genero
# 0  Douglas     48    1.85     70      M
# 1  Daniela     10    1.23     22      F
# 2    Pedro     65    1.75     87      M
# 3    Maria     64    1.67     64      F
# 4  Eduardo     42    1.82     96      M
# 5    Ester     37    1.73     68      F

# %%
# voltando aos nomes originais
df.rename(columns={'massa':'peso','genero':'sexo'},inplace=True)
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     48    1.85    70    M
# 1  Daniela     10    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
# Método 03
df.rename({'peso':'massa','sexo':'genero'},axis=1,inplace=True)

# %%
# voltando aos nomes originais
df.rename(columns={'massa':'peso','genero':'sexo'},inplace=True)
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     48    1.85    70    M
# 1  Daniela     10    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
# Método 4
df.rename({'peso':'massa','sexo':'genero'},axis='columns',inplace=True)
display(df)
# Out:
#       nome  idade  altura  massa genero  massa
# 0    Pedro     65    1.75     87      M    NaN
# 1    Maria     64    1.67     64      F    NaN
# 2  Douglas     48    1.85     70      M    NaN
# 3  Eduardo     42    1.82     87      M   87.0
# 4    Ester     40    1.75     65      F    NaN
# 5  Daniela     65    1.23     22      F    NaN

# %%
# voltando aos nomes originais
df.rename(columns={'massa':'peso','genero':'sexo'},inplace=True)
display(df)
# Out:
#       nome  idade  altura  peso sexo
# 0  Douglas     48    1.85    70    M
# 1  Daniela     10    1.23    22    F
# 2    Pedro     65    1.75    87    M
# 3    Maria     64    1.67    64    F
# 4  Eduardo     42    1.82    96    M
# 5    Ester     37    1.73    68    F

# %%
# Método 05
df.columns.values[3] = 'massa'
df.columns.values[4] = 'genero'
display(df)
# Out:
#       nome  idade  altura  massa genero
# 0  Douglas     48    1.85     70      M
# 1  Daniela     10    1.23     22      F
# 2    Pedro     65    1.75     87      M
# 3    Maria     64    1.67     64      F
# 4  Eduardo     42    1.82     96      M
# 5    Ester     37    1.73     68      F

# %% [markdown]
# # Renomeando linhas

# %%
# Método1
df.rename({0:'pai',1:'filha'}, axis=0, inplace=True)
display(df)
# Out:
#           nome  idade  altura  massa genero
# pai    Douglas     48    1.85     70      M
# filha  Daniela     10    1.23     22      F
# 2        Pedro     65    1.75     87      M
# 3        Maria     64    1.67     64      F
# 4      Eduardo     42    1.82     96      M
# 5        Ester     37    1.73     68      F

# %%
# Voltando ao original
df.rename({'pai':0,'filha':1}, axis=0, inplace=True)
display(df)
# Out:
#       nome  idade  altura  massa genero
# 0  Douglas     48    1.85     70      M
# 1  Daniela     10    1.23     22      F
# 2    Pedro     65    1.75     87      M
# 3    Maria     64    1.67     64      F
# 4  Eduardo     42    1.82     96      M
# 5    Ester     37    1.73     68      F

# %%
# Método 2
df.rename({0:'pai',1:'filha'}, axis='rows', inplace=True)
display(df)
# Out:
#           nome  idade  altura  massa genero
# pai    Douglas     48    1.85     70      M
# filha  Daniela     10    1.23     22      F
# 2        Pedro     65    1.75     87      M
# 3        Maria     64    1.67     64      F
# 4      Eduardo     42    1.82     96      M
# 5        Ester     37    1.73     68      F

# %%
# Resetando os rótulos do índice
df.reset_index(inplace=True, drop=True)
display(df)
# Out:
#       nome  idade  altura  massa genero
# 0  Douglas     48    1.85     70      M
# 1  Daniela     10    1.23     22      F
# 2    Pedro     65    1.75     87      M
# 3    Maria     64    1.67     64      F
# 4  Eduardo     42    1.82     96      M
# 5    Ester     37    1.73     68      F

# %%
# Excluindo uma linha
df.drop(5, axis=0,inplace=True)
display(df)
# Out:
#       nome  idade  altura  massa genero
# 0  Douglas     48    1.85     70      M
# 1  Daniela     10    1.23     22      F
# 2    Pedro     65    1.75     87      M
# 3    Maria     64    1.67     64      F
# 4  Eduardo     42    1.82     96      M

# %%
# Inserindo Linhas
df.loc[5] = ['Ester',40, 1.74, 65, 'F']
display(df)
# Out:
#       nome  idade  altura  massa genero
# 0  Douglas     48    1.85     70      M
# 1  Daniela     10    1.23     22      F
# 2    Pedro     65    1.75     87      M
# 3    Maria     64    1.67     64      F
# 4  Eduardo     42    1.82     96      M
# 5    Ester     40    1.74     65      F

# %%
# Atalho para exibir informações de uma coluna
df['nome']
# Out:
# 0    Douglas
# 1    Daniela
# 2      Pedro
# 3      Maria
# 4    Eduardo
# 5      Ester
# Name: nome, dtype: object

# %%
# Atalho2
df.nome
# Out:
# 0    Douglas
# 1    Daniela
# 2      Pedro
# 3      Maria
# 4    Eduardo
# 5      Ester
# Name: nome, dtype: object

# %%
df
# Out:
#       nome  idade  altura  massa genero  massa
# 0    Pedro     65    1.75     87      M    NaN
# 1    Maria     64    1.67     64      F    NaN
# 2  Douglas     48    1.85     70      M    NaN
# 3  Eduardo     42    1.82     87      M   87.0
# 4    Ester     40    1.75     65      F    NaN
# 5  Daniela     65    1.23     22      F    NaN

# %%
# Inserindo coluna
df['imc'] = round(df['massa']/df['altura']**2,2)
display(df)
# Out:
#       nome  idade  altura  massa genero    imc
# 0  Douglas     45    1.85     70      M  20.45
# 1  Daniela      7    1.23     22      F  14.54
# 2    Pedro     65    1.75     87      M  28.41
# 3    Maria     64    1.67     64      F  22.95
# 4  Eduardo     42    1.82     96      M  28.98
# 5    Ester     37    1.73     68      F  22.72

# %% [markdown]
# # Ordenando o DF

# %%
# Ordenar um df de forma crescente
df.sort_values('idade',inplace=True)
display(df)
# Out:
#       nome  idade  altura  massa genero
# 1  Daniela     10    1.23     22      F
# 5    Ester     40    1.74     65      F
# 4  Eduardo     42    1.82     96      M
# 0  Douglas     48    1.85     70      M
# 3    Maria     64    1.67     64      F
# 2    Pedro     65    1.75     87      M

# %%
df.reset_index(inplace=True, drop=True)
display(df)
# Out:
#       nome  idade  altura  massa genero
# 0  Daniela     10    1.23     22      F
# 1    Ester     40    1.74     65      F
# 2  Eduardo     42    1.82     96      M
# 3  Douglas     48    1.85     70      M
# 4    Maria     64    1.67     64      F
# 5    Pedro     65    1.75     87      M

# %%
# Ordenando de forma descrescente
df.sort_values('idade',inplace=True, ascending=False)
display(df)
# Out:
#       nome  idade  altura  massa genero
# 5    Pedro     65    1.75     87      M
# 4    Maria     64    1.67     64      F
# 3  Douglas     48    1.85     70      M
# 2  Eduardo     42    1.82     96      M
# 1    Ester     40    1.74     65      F
# 0  Daniela     10    1.23     22      F

# %%
df.reset_index(inplace=True, drop=True)
display(df)
# Out:
#       nome  idade  altura  massa genero
# 0    Pedro     65    1.75     87      M
# 1    Maria     64    1.67     64      F
# 2  Douglas     48    1.85     70      M
# 3  Eduardo     42    1.82     96      M
# 4    Ester     40    1.74     65      F
# 5  Daniela     10    1.23     22      F

# %%
'''
Exercício:
Crie um dataframe com as seguintes medidas descritivas a partir do
df original:
1 - contagem - (count)
2 - media - (mean)
3 - mediana - (criar linha nova)
4 - moda - (criar linha nova)
5 - variância - (criar linha nova)
6 - desvio padrão - (std)
7 - valor mínimo - (min)
8 - Q1 - (25%)
9 - Q2 - (50%)
10 -Q3 - (75%)
11 -Valor máximo (max)
12 -AIQ - (criar linha nova)
13 -LI - (criar linha nova)
14 -LS -(criar linha nova)
'''
# Out:
# '\nExercício:\nCrie um dataframe com as seguintes medidas descritivas a partir do\ndf original:\n1 - contagem - (count)\n2 - media - (mean)\n3 - mediana - (criar linha nova)\n4 - moda - (criar linha nova)\n5 - variância - (criar linha nova)\n6 - desvio padrão - (std)\n7 - valor mínimo - (min)\n8 - Q1 - (25%)\n9 - Q2 - (50%)\n10 -Q3 - (75%)\n11 -Valor máximo (max)\n12 -AIQ - (criar linha nova)\n13 -LI - (criar linha nova)\n14 -LS -(criar linha nova)\n'

# %%
# Reconstruindo o dataframe medidas
medidas = df.describe()

# %%
# Transformando a linha de Q2 em uma lista chamada mediana
mediana = list(medidas.loc['50%'])
print(mediana)
# Out:
# [54.5, 1.74, 78.5, 22.835]

# %%
# Devolvendo a lista mediana ao df Medidas
medidas.loc['mediana'] = mediana
medidas
# Out:
#              idade    altura      massa        imc
# count     6.000000  6.000000   6.000000   6.000000
# mean     48.000000  1.663333  71.666667  23.008333
# std      22.627417  0.220061  26.628306   5.351319
# min       7.000000  1.230000  22.000000  14.540000
# 25%      42.750000  1.685000  68.500000  21.017500
# 50%      54.500000  1.740000  78.500000  22.835000
# 75%      64.750000  1.750000  87.000000  27.045000
# max      65.000000  1.850000  96.000000  28.980000
# mediana  54.500000  1.740000  78.500000  22.835000

# %%
# Forçando o DF original ter moda (parte 1)
df.loc[4,'altura'] = 1.75
df.loc[3, 'massa'] = 87

# %%
# Forçando o DF original ter moda (parte 1)
df.loc[5,'idade'] = 65

# %%
# Calculando a moda de cada atributo quant usando o pandas
moda = [df['idade'].mode().loc[0],df['altura'].mode().loc[0],df['massa'].mode().loc[0],df['imc'].mode().loc[0]]
print(moda)
# Out:
# [65, 1.75, 87, 14.54]

# %%
'''
Criando uma lista vazio de variância, transformando std em uma lista
chamada desvio, iterando sobre a lista desvio e appendando o resultado das
iterções na lista variancia
'''
variancia = []
desvio = list(medidas.loc['std'])
for i in range(len(desvio)):
  variancia.append(round(desvio[i]**2,6))
print(variancia)
# Out:
# [512.0, 0.048427, 709.066667, 28.636617]

# %%
'''
Transformando primeiro e terceiro quartis em listas,
criando listas vazias para aiq, li e ls, iterando sobre q1 e q3
para appendar na lista aiq
'''
q1 = list(medidas.loc['25%'])
q3 = list(medidas.loc['75%'])
aiq = []
li = []
ls = []
for i in range(len(q1)):
  aiq.append(round(q3[i]-q1[i],6))
print(aiq)
# Out:
# [22.0, 0.065, 18.5, 6.0275]

# %%
'''
Iterando sobre a lista aiq para appendar na listas li e ls
'''
for i in range(len(aiq)):
  li.append(round(q1[i] - (1.5*aiq[i]),6))
  ls.append(round(q3[i] + (1.5*aiq[i]),6))

# %%
'''
Inserindo as listas criadas no df medidas
'''
medidas.loc['moda'] = moda
medidas.loc['variancia'] = variancia
medidas.loc['LI'] = li
medidas.loc['LS'] = ls
medidas.loc['AIQ'] = aiq
display(medidas)
# Out:
#                 idade    altura       massa        imc
# count        6.000000  6.000000    6.000000   6.000000
# mean        48.000000  1.663333   71.666667  23.008333
# std         22.627417  0.220061   26.628306   5.351319
# min          7.000000  1.230000   22.000000  14.540000
# 25%         42.750000  1.685000   68.500000  21.017500
# 50%         54.500000  1.740000   78.500000  22.835000
# 75%         64.750000  1.750000   87.000000  27.045000
# max         65.000000  1.850000   96.000000  28.980000
# mediana     54.500000  1.740000   78.500000  22.835000
# moda        65.000000  1.750000   87.000000  14.540000
# variancia  512.000000  0.048427  709.066667  28.636617
# LI           9.750000  1.587500   40.750000  11.976250
# LS          97.750000  1.847500  114.750000  36.086250
# AIQ         22.000000  0.065000   18.500000   6.027500

# %%
'''
Renomeando as listas de acordo com os nomes pedidos no enunciado
'''
medidas.rename({'count':'Contagem','mean':'Média',
                'std':'Desvio Padrão','min':'Valor Mínimo','25%':'Q1',
                '50%':'Q2','75%':'Q3','max':'Valor Máximo'}, axis=0, inplace=True)

# %%
'''
Reordenando as linhas de acordo com o que foi pedido
'''
medidas = medidas.loc[['Contagem','Média','mediana','moda','variancia',
                       'Desvio Padrão', 'Valor Mínimo', 'Q1', 'Q2', 'Q3',
                       'Valor Máximo', 'AIQ', 'LI', 'LS']]
display(medidas)
# Out:
#                     idade    altura       massa        imc
# Contagem         6.000000  6.000000    6.000000   6.000000
# Média           48.000000  1.663333   71.666667  23.008333
# mediana         54.500000  1.740000   78.500000  22.835000
# moda            65.000000  1.750000   87.000000  14.540000
# variancia      512.000000  0.048427  709.066667  28.636617
# Desvio Padrão   22.627417  0.220061   26.628306   5.351319
# Valor Mínimo     7.000000  1.230000   22.000000  14.540000
# Q1              42.750000  1.685000   68.500000  21.017500
# Q2              54.500000  1.740000   78.500000  22.835000
# Q3              64.750000  1.750000   87.000000  27.045000
# Valor Máximo    65.000000  1.850000   96.000000  28.980000
# AIQ             22.000000  0.065000   18.500000   6.027500
# LI               9.750000  1.587500   40.750000  11.976250
# LS              97.750000  1.847500  114.750000  36.086250

# %% [markdown]
# # Agrupamentos

# %%
df = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vR2snMwL0lRHwNv3ilck0T98nhhyAqzmU5oQMKY4nwKZu_0FkiGo8U7ZXvA63CQOg2bYfmhKc6c-dL1/pub?gid=0&single=true&output=csv')
display(df)
# Out:
#    matricula      nome     cidade estado    pais  idade departamento  \
# 0          1     Lucas    Atibaia     SP  Brasil     35      Compras
# 1          2       Ana  São Paulo     SP  Brasil     29       Vendas
# 2          3     Luiza     Santos     SP  Brasil     38     Finanças
# 3          4  Fernando    Atibaia     SP  Brasil     36    Marketing
# 4          5    Sandra    Atibaia     SP  Brasil     28     Produção
# 5          6   Douglas   Bragança     SP  Brasil     29     Finanças
# 6          7   Eduardo    Extrema     MG  Brasil     30    Marketing
# 7          8     Ester    Itapeva     MG  Brasil     29      Compras
# 8          9     Pedro    Extrema     MG  Brasil     30    Marketing
# 9         10     Maria    Extrema     MG  Brasil     40     Produção
#
#          cargo  salario escolaridade  nota
# 0      Gerente    25000     Superior     8
# 1  Coordenador    12000     Superior     6
# 2      Gerente    28000          MBA     9
# 3      Diretor    40000     Mestrado     7
# 4     Analista    23000     Superior     5
# 5     Analista    11000     Superior     9
# 6      Gerente    12000          MBA     4
# 7     Analista    10000     Superior     2
# 8     Analista    13000     Superior     1
# 9     Analista    12000          MBA     7

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 10 entries, 0 to 9
# Data columns (total 11 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   matricula     10 non-null     int64
#  1   nome          10 non-null     object
#  2   cidade        10 non-null     object
#  3   estado        10 non-null     object
#  4   pais          10 non-null     object
#  5   idade         10 non-null     int64
#  6   departamento  10 non-null     object
#  7   cargo         10 non-null     object
#  8   salario       10 non-null     int64
#  9   escolaridade  10 non-null     object
#  10  nota          10 non-null     int64
# dtypes: int64(4), object(7)
# memory usage: 1008.0+ bytes

# %%
'''
Crie uma visão do salário médio por cidade
'''
df[['cidade','salario']].groupby('cidade').mean()
# Out:
#                 salario
# cidade
# Atibaia    29333.333333
# Bragança   11000.000000
# Extrema    12333.333333
# Itapeva    10000.000000
# Santos     28000.000000
# São Paulo  12000.000000

# %%
'''
Crie uma visão do salário médio agrupado por departamento e por
cargo
'''
df[['departamento','cargo','salario']].groupby(['departamento','cargo']).mean()
# Out:
#                           salario
# departamento cargo
# Compras      Analista     10000.0
#              Gerente      25000.0
# Finanças     Analista     11000.0
#              Gerente      28000.0
# Marketing    Analista     13000.0
#              Diretor      40000.0
#              Gerente      12000.0
# Produção     Analista     17500.0
# Vendas       Coordenador  12000.0

# %%
'''
Crie uma visão dos 25% menores salários agrupados por cargos
'''
df[['cargo','salario']].groupby('cargo').quantile(0.25)
# Out:
#              salario
# cargo
# Analista     11000.0
# Coordenador  12000.0
# Diretor      40000.0
# Gerente      18500.0

# %%
'''
Vamor fazer uma consulta que retorne apenas os nomes e salários,
cujo salário seja maior que 20.000
'''
df.loc[df['salario'] > 20000,['nome','salario']]
# Out:
#        nome  salario
# 0     Lucas    25000
# 2     Luiza    28000
# 3  Fernando    40000
# 4    Sandra    23000

# %%
'''
Alternativa ao código do bloco anterior
'''
df.query('salario > 20000')[['nome','cargo','salario']]
# Out:
#        nome     cargo  salario
# 0     Lucas   Gerente    25000
# 2     Luiza   Gerente    28000
# 3  Fernando   Diretor    40000
# 4    Sandra  Analista    23000

# %%
'''
Faça uma consulta que retorne todos os nomes de
funcionários de Atibaia
'''
df.query('cidade == "Atibaia"')[['nome','cidade']]
# Out:
#        nome   cidade
# 0     Lucas  Atibaia
# 3  Fernando  Atibaia
# 4    Sandra  Atibaia

# %%
'''
Faça uma consulta que retorne os nomes e idades de funcionários
acima de 30 anos
'''
df.query('idade > 30')[['nome', 'idade']]
# Out:
#        nome  idade
# 0     Lucas     35
# 2     Luiza     38
# 3  Fernando     36
# 9     Maria     40

# %%
'''
Faça uma consulta que retorne os nomes e idades de funcionários
acima da média de idade
'''
df.query('idade > (idade.mean())')[['nome','idade']]
# Out:
#        nome  idade
# 0     Lucas     35
# 2     Luiza     38
# 3  Fernando     36
# 9     Maria     40

# %%
'''
Faça uma consulta que retorne os nomes e idades de funcionários
abixo da média de idade
'''
df.query('idade < (idade.mean())')[['nome','idade']]
# Out:
#       nome  idade
# 1      Ana     29
# 4   Sandra     28
# 5  Douglas     29
# 6  Eduardo     30
# 7    Ester     29
# 8    Pedro     30

# %%
nome = ['Douglas','Daniela','Pedro','Maria','Eduardo','Ester']
idade = [45,7,65,64,42,37]
altura = [1.85,1.23,1.75,1.67,1.82,1.73]
peso = [70,22,87,64,96,68]
sexo = ['M','F','M','F','M','F']
df = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])

# %%
nome = ['Douglas1','Daniela1']
idade = [45,7]
altura = [1.85,1.23]
peso = [70,22]
sexo = ['M','F']
df2 = pd.DataFrame(zip(nome,idade,altura,peso,sexo),
                  columns=['nome','idade','altura','peso','sexo'])

# %% [markdown]
# # Concatenação de tabelas

# %%
uniao = pd.concat([df,df2])
display(uniao)
# Out:
#        nome  idade  altura  peso sexo
# 0   Douglas     45    1.85    70    M
# 1   Daniela      7    1.23    22    F
# 2     Pedro     65    1.75    87    M
# 3     Maria     64    1.67    64    F
# 4   Eduardo     42    1.82    96    M
# 5     Ester     37    1.73    68    F
# 0  Douglas1     45    1.85    70    M
# 1  Daniela1      7    1.23    22    F

# %%
# DataFrame 1
df1 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Nome': ['Alice', 'Roberto', 'Carlos'],
    'Salário': [50000, 60000, 70000]
})
display(df1)
# Out:
#    ID     Nome  Salário
# 0   1    Alice    50000
# 1   2  Roberto    60000
# 2   3   Carlos    70000

# %%
# DataFrame 2
df2 = pd.DataFrame({
    'ID': [4, 5, 6],
    'Nome': ['David', 'Eva', 'Francisco'],
    'Salário': [80000, 90000, 100000]
})
display(df2)
# Out:
#    ID       Nome  Salário
# 0   4      David    80000
# 1   5        Eva    90000
# 2   6  Francisco   100000

# %%
geral = pd.concat([df1,df2],ignore_index=True)
display(geral)
# Out:
#    ID       Nome  Salário
# 0   1      Alice    50000
# 1   2    Roberto    60000
# 2   3     Carlos    70000
# 3   4      David    80000
# 4   5        Eva    90000
# 5   6  Francisco   100000

# %%
# DataFrame 1
df1 = pd.DataFrame({
    'ID': [1, 2, 3],
    'Nome': ['Alice', 'Roberto', 'Carlos']
})
display(df1)
# Out:
#    ID     Nome
# 0   1    Alice
# 1   2  Roberto
# 2   3   Carlos

# %%
# DataFrame 2
df2 = pd.DataFrame({
    'Salário': [50000, 60000, 70000],
    'Departamento': ['TI', 'RH', 'Marketing']
})
display(df2)
# Out:
#    Salário Departamento
# 0    50000           TI
# 1    60000           RH
# 2    70000    Marketing

# %%
geral2 = pd.concat([df1,df2],axis=1)
display(geral2)
# Out:
#    ID     Nome  Salário Departamento
# 0   1    Alice    50000           TI
# 1   2  Roberto    60000           RH
# 2   3   Carlos    70000    Marketing

# %% [markdown]
# # Fusão

# %%
# Fusão de tabelas (merge)
# DataFrame 1
df1 = pd.DataFrame({
    'ID': [1, 2, 3, 4],
    'Nome': ['Alice', 'Roberto', 'Carlos', 'David'],
    'Salário': [50000, 60000, 70000, 80000]
})
display(df1)
# Out:
#    ID     Nome  Salário
# 0   1    Alice    50000
# 1   2  Roberto    60000
# 2   3   Carlos    70000
# 3   4    David    80000

# %%
# DataFrame 2
df2 = pd.DataFrame({
    'ID': [1, 2, 3, 5],
    'Departamento': ['TI', 'RH', 'Marketing', 'Vendas']
})
display(df2)
# Out:
#    ID Departamento
# 0   1           TI
# 1   2           RH
# 2   3    Marketing
# 3   5       Vendas

# %%
inner_join = pd.merge(df1, df2, on='ID', how='inner')
display(inner_join)
# Out:
#    ID     Nome  Salário Departamento
# 0   1    Alice    50000           TI
# 1   2  Roberto    60000           RH
# 2   3   Carlos    70000    Marketing

# %%
left_join = pd.merge(df1, df2, on='ID', how='left')
display(left_join)
# Out:
#    ID     Nome  Salário Departamento
# 0   1    Alice    50000           TI
# 1   2  Roberto    60000           RH
# 2   3   Carlos    70000    Marketing
# 3   4    David    80000          NaN

# %%
right_join = pd.merge(df1, df2, on='ID', how='right')
display(right_join)
# Out:
#    ID     Nome  Salário Departamento
# 0   1    Alice  50000.0           TI
# 1   2  Roberto  60000.0           RH
# 2   3   Carlos  70000.0    Marketing
# 3   5      NaN      NaN       Vendas

# %%
outer_join = pd.merge(df1, df2, on='ID', how='outer')
display(outer_join)
# Out:
#    ID     Nome  Salário Departamento
# 0   1    Alice  50000.0           TI
# 1   2  Roberto  60000.0           RH
# 2   3   Carlos  70000.0    Marketing
# 3   4    David  80000.0          NaN
# 4   5      NaN      NaN       Vendas

# %%
# DataFrame 1
df1 = pd.DataFrame({
    'ID': [1, 2, 3, 4],
    'Nome': ['Alice', 'Roberto', 'Carlos', 'David'],
    'Salário': [50000, 60000, 70000, 80000]
})
display(df1)
# Out:
#    ID     Nome  Salário
# 0   1    Alice    50000
# 1   2  Roberto    60000
# 2   3   Carlos    70000
# 3   4    David    80000

# %%
# DataFrame 2
df2 = pd.DataFrame({
    'ID': [1, 2, 3, 5],
    'Departamento': ['TI', 'RH', 'Marketing', 'Vendas']
})
display(df2)
# Out:
#    ID Departamento
# 0   1           TI
# 1   2           RH
# 2   3    Marketing
# 3   5       Vendas

# %%
df1.set_index('ID', inplace=True)
df2.set_index('ID', inplace=True)

# %%
inner_join2 = df1.join(df2,how='inner')
display(inner_join2)
# Out:
#        Nome  Salário Departamento
# ID
# 1     Alice    50000           TI
# 2   Roberto    60000           RH
# 3    Carlos    70000    Marketing

# %%
inner_join2 = df1.join(df2,how='left')
display(inner_join2)
# Out:
#        Nome  Salário Departamento
# ID
# 1     Alice    50000           TI
# 2   Roberto    60000           RH
# 3    Carlos    70000    Marketing
# 4     David    80000          NaN

# %%
inner_join2 = df1.join(df2,how='right')
display(inner_join2)
# Out:
#        Nome  Salário Departamento
# ID
# 1     Alice  50000.0           TI
# 2   Roberto  60000.0           RH
# 3    Carlos  70000.0    Marketing
# 5       NaN      NaN       Vendas

# %%
inner_join2 = df1.join(df2,how='outer')
display(inner_join2)
# Out:
#        Nome  Salário Departamento
# ID
# 1     Alice  50000.0           TI
# 2   Roberto  60000.0           RH
# 3    Carlos  70000.0    Marketing
# 4     David  80000.0          NaN
# 5       NaN      NaN       Vendas

# %%
cliente = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQW3fP3j4qoiMGBXDAGzg_9IW2b3zgjdkVKLsURNVe9QezpHXimWfKle_55CQQtkeWL69OAASBDNdk8/pub?gid=2073489257&single=true&output=csv')
display(cliente)
# Out:
#    codcliente              nome           cidade sexo estado estadocivil
# 0           1         Ana Silva  Duque de Caxias    F     RJ           C
# 1           2     Bruna Pereira          Niterói    F     RJ           C
# 2           3  Túlio Nascimento  Duque de Caxias    M     RJ           S
# 3           4    Fernando Souza         Campinas    M     SP           S
# 4           5     Lúcia Andrade        São Paulo    F     SP           C

# %%
aluguel = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRncyLGO1iOo2H53JaryzVF1GPjUhWl9DsN7TZROCDxaP85iCwl5aW5ffBEzqtpAMRNYkd7eO5ehmgn/pub?gid=1581881382&single=true&output=csv')
display(aluguel)
# Out:
#    codaluguel  codcliente  codcarro data_aluguel
# 0           1           3         2   2023-04-01
# 1           2           2         1   2023-04-02
# 2           3           2         1   2023-04-03
# 3           4           2         3   2023-04-04
# 4           5           1         4   2023-04-05
# 5           6           1         4   2023-04-13
# 6           7           1         1   2023-04-15
# 7           8           5         2   2023-04-19
# 8           9           5         2   2023-04-21
# 9          10           3         1   2023-04-25

# %%
carro = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSznlX7UXeH_LeKcNteiDnWvdwZyydAQl0_x8NU9cx6G00Zh7SMrjoUuNpytVq7U-iQVzQNJ7jC7GpY/pub?gid=306989914&single=true&output=csv')
display(carro)
# Out:
#    codcarro  codmarca modelo  valor
# 0         1         1     Ka  100.0
# 1         2         2   Argo  150.0
# 2         3         3   Onix  170.0
# 3         4         4   Polo  150.0
# 4         5         5   Kwid  120.0

# %%
marca = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSI-4_QEFwZ6eDGwUDlip0_PGBn7d_F7j59UwXmRvWbQFyy01ENPatjkbO1E8k5ZW5lqSY9ox112j7X/pub?gid=1160143272&single=true&output=csv')
display(marca)
# Out:
#    codmarca       marca
# 0         1        Ford
# 1         2        Fiat
# 2         3   Chevrolet
# 3         4  Volkswagen
# 4         5     Renault

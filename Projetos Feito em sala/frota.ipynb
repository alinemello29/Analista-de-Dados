# %%
import pandas as pd

# %%
cliente = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRizO37GDBc5KOKED10_N0ndnAX3jQE4qi_VeL6v9BBSgX3uePV-HFcN56gDF-61QPBOV83zuvi4tkZ/pub?gid=1986097323&single=true&output=csv')
cliente
# Out:
#      ID Cliente           Cidade  UF
# 0             1  Duque de Caxias  RJ
# 1             2         Contagem  MG
# 2             3      Barra Mansa  RJ
# 3             4    Nova Friburgo  RJ
# 4             5         Contagem  MG
# ..          ...              ...  ..
# 995         996          Castelo  ES
# 996         997   Belo Horizonte  MG
# 997         998           Muriaé  MG
# 998         999         Anchieta  ES
# 999        1000          Resende  RJ
#
# [1000 rows x 3 columns]

# %%
veiculo = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRizO37GDBc5KOKED10_N0ndnAX3jQE4qi_VeL6v9BBSgX3uePV-HFcN56gDF-61QPBOV83zuvi4tkZ/pub?gid=2061311847&single=true&output=csv')
veiculo
# Out:
#     ID Veiculo     Placa          Marca Tipo Veículo       Baú
# 0            1  REQ-1358     Volkswagen        TRUCK  Alumínio
# 1            2  SKY-3175  Mercedes-Benz         TOCO     Sider
# 2            3  THU-9587           Ford      CARRETA     Sider
# 3            4  TGM-4422          Iveco         TOCO     Sider
# 4            5  RDP-3433          Iveco        TRUCK  Alumínio
# 5            6  TGY-1709          Iveco          VUC     Sider
# 6            7  SAL-2971          Iveco        TRUCK     Sider
# 7            8  SEO-4815     Volkswagen         TOCO     Sider
# 8            9  SDW-8899           Ford         TOCO     Sider
# 9           10  SCS-3852          Iveco          3/4  Alumínio
# 10          11  RIV-3153         Scania        TRUCK  Alumínio
# 11          12  RCU-1767         Scania         TOCO     Sider
# 12          13  SFM-4207           Ford        TRUCK  Alumínio
# 13          14  SBT-2107          Iveco        TRUCK     Sider
# 14          15  SFN-2018  Mercedes-Benz          VUC     Sider
# 15          16  RJL-3865          Volvo         TOCO  Alumínio
# 16          17  TCT-5023     Volkswagen          VUC  Alumínio
# 17          18  TKW-5617           Ford         TOCO     Sider
# 18          19  SDX-8015          Iveco          3/4  Alumínio
# 19          20  TAV-2719  Mercedes-Benz          VUC     Sider
# 20          21  RHM-7270  Mercedes-Benz         TOCO     Sider
# 21          22  RHX-5540  Mercedes-Benz          VUC  Alumínio
# 22          23  SEL-4612  Mercedes-Benz         TOCO     Sider
# 23          24  TEU-5881  Mercedes-Benz      CARRETA     Sider
# 24          25  TJY-2132     Volkswagen        TRUCK     Sider
# 25          26  RDY-9247          Volvo      CARRETA  Alumínio
# 26          27  SEY-1234           Ford         TOCO  Alumínio
# 27          28  SDW-3162         Scania        TRUCK     Sider
# 28          29  TAW-1116  Mercedes-Benz      CARRETA     Sider
# 29          30  RBX-7957     Volkswagen         TOCO  Alumínio
# 30          31  RCY-4353     Volkswagen          VUC  Alumínio
# 31          32  TEZ-1123     Volkswagen         TOCO     Sider
# 32          33  SAX-9434           Ford      CARRETA     Sider
# 33          34  RAV-3583           Ford      CARRETA  Alumínio
# 34          35  SDY-8086  Mercedes-Benz         TOCO  Alumínio
# 35          36  RBV-8540  Mercedes-Benz      CARRETA     Sider
# 36          37  SEY-1363          Iveco          VUC     Sider
# 37          38  SDV-3240          Iveco         TOCO  Alumínio
# 38          39  TCW-7717          Volvo         TOCO  Alumínio
# 39          40  SBW-6046     Volkswagen         TOCO  Alumínio
# 40          41  RCW-7596           Ford      CARRETA  Alumínio
# 41          42  TCY-4657  Mercedes-Benz          3/4     Sider
# 42          43  RBW-2406          Volvo        TRUCK     Sider
# 43          44  SCV-8966          Iveco      CARRETA     Sider
# 44          45  TAZ-4787           Ford          3/4     Sider
# 45          46  SAZ-7021         Scania          3/4     Sider
# 46          47  SDV-6530  Mercedes-Benz          3/4     Sider
# 47          48  TEW-2419          Volvo          VUC     Sider
# 48          49  TEY-5454  Mercedes-Benz        TRUCK     Sider
# 49          50  SDW-9549  Mercedes-Benz        TRUCK     Sider

# %%
frete = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRizO37GDBc5KOKED10_N0ndnAX3jQE4qi_VeL6v9BBSgX3uePV-HFcN56gDF-61QPBOV83zuvi4tkZ/pub?gid=124219553&single=true&output=csv')
frete.rename(columns={'Peso (KG)':'Peso'},inplace=True)
frete
# Out:
#             Data  ID Cliente  ID Veiculo  Numero Documento Fiscal  \
# 0       1/1/2018         159          11                   945693
# 1       1/2/2018         292          12                   161542
# 2       1/3/2018         543           6                   357544
# 3       1/4/2018          53          12                   498247
# 4       1/5/2018         166          23                   770040
# ...          ...         ...         ...                      ...
# 80496  7/16/2018         209          28                   744259
# 80497  7/17/2018         233          42                   896113
# 80498  7/18/2018         654          21                   503155
# 80499  7/19/2018          68          33                   671646
# 80500  7/20/2018         796          28                   333320
#
#                     Viagem Valor do Frete Líquido    Peso Valor da Mercadoria
# 0      01/01/2018-RIV-3153                2625,98   48,65           23371,222
# 1      02/01/2018-RCU-1767                  977,9  366,06             4693,92
# 2      03/01/2018-TGY-1709                 292,03  490,26             700,872
# 3      04/01/2018-RCU-1767                 423,45  507,44            3429,945
# 4      05/01/2018-SEL-4612                4487,14  479,52           14358,848
# ...                    ...                    ...     ...                 ...
# 80496  16/07/2018-SDW-3162                 747,62  552,14            6205,246
# 80497  17/07/2018-TCY-4657                1546,28  589,76            6803,632
# 80498  18/07/2018-RHM-7270                4268,13  581,96           40547,235
# 80499  19/07/2018-SAX-9434                3179,45  538,75            7312,735
# 80500  20/07/2018-SDW-3162                2027,19  412,35           11352,264
#
# [80501 rows x 8 columns]

# %%
km = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRizO37GDBc5KOKED10_N0ndnAX3jQE4qi_VeL6v9BBSgX3uePV-HFcN56gDF-61QPBOV83zuvi4tkZ/pub?gid=1353331406&single=true&output=csv')
km.rename(columns={'Manut.':'Manutencao'},inplace=True)
km
# Out:
#             Mês  ID Veiculo  Km percorridos Gasto com Combustível  Manutencao  \
# 0      1/1/2018           1             681                 953,4         722
# 1      1/1/2018           2              68                   340         289
# 2      1/1/2018           3             314                 659,4         205
# 3      1/1/2018           4             346                1072,6         960
# 4      1/1/2018           5             850                  2125         141
# ...         ...         ...             ...                   ...         ...
# 1195  12/1/2019          46             405                1903,5         716
# 1196  12/1/2019          47             925                2127,5         670
# 1197  12/1/2019          48             879                   879         808
# 1198  12/1/2019          49              17                   3,4         460
# 1199  12/1/2019          50             719                 575,2         936
#
#       Custos Fixos
# 0               18
# 1              357
# 2              771
# 3              632
# 4              770
# ...            ...
# 1195           713
# 1196           278
# 1197           121
# 1198           337
# 1199           391
#
# [1200 rows x 6 columns]

# %%
from google.colab import files
from google.cloud import bigquery
from google.colab import auth


# Autenticar no Google Cloud
auth.authenticate_user()

# Criar o cliente do BigQuery
client = bigquery.Client()

# Definir o ID do projeto e o ID da tabela
project_id = 'turmas-dados'
table_id = 'turmas-dados.logistica2.cliente'

# Enviar o DataFrame para o BigQuery
cliente.to_gbq(table_id, project_id=project_id, if_exists='replace')
# Out:
# <ipython-input-21-98fed32b8787>:17: FutureWarning: to_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.to_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.to_gbq
#   cliente.to_gbq(table_id, project_id=project_id, if_exists='replace')
# 100%|██████████| 1/1 [00:00<00:00, 1877.49it/s]

# %%
from google.colab import files
from google.cloud import bigquery
from google.colab import auth


# Autenticar no Google Cloud
auth.authenticate_user()

# Criar o cliente do BigQuery
client = bigquery.Client()

# Definir o ID do projeto e o ID da tabela
project_id = 'turmas-dados'
table_id = 'turmas-dados.logistica2.veiculo'

# Enviar o DataFrame para o BigQuery
veiculo.to_gbq(table_id, project_id=project_id, if_exists='replace')
# Out:
# <ipython-input-22-2387a5ac2611>:17: FutureWarning: to_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.to_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.to_gbq
#   veiculo.to_gbq(table_id, project_id=project_id, if_exists='replace')
# 100%|██████████| 1/1 [00:00<00:00, 840.71it/s]

# %%
from google.colab import files
from google.cloud import bigquery
from google.colab import auth


# Autenticar no Google Cloud
auth.authenticate_user()

# Criar o cliente do BigQuery
client = bigquery.Client()

# Definir o ID do projeto e o ID da tabela
project_id = 'turmas-dados'
table_id = 'turmas-dados.logistica2.frete'

# Enviar o DataFrame para o BigQuery
frete.to_gbq(table_id, project_id=project_id, if_exists='replace')
# Out:
# <ipython-input-23-01bf6824db38>:17: FutureWarning: to_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.to_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.to_gbq
#   frete.to_gbq(table_id, project_id=project_id, if_exists='replace')
# 100%|██████████| 1/1 [00:00<00:00, 685.57it/s]

# %%
from google.colab import files
from google.cloud import bigquery
from google.colab import auth


# Autenticar no Google Cloud
auth.authenticate_user()

# Criar o cliente do BigQuery
client = bigquery.Client()

# Definir o ID do projeto e o ID da tabela
project_id = 'turmas-dados'
table_id = 'turmas-dados.logistica2.km'

# Enviar o DataFrame para o BigQuery
km.to_gbq(table_id, project_id=project_id, if_exists='replace')
# Out:
# <ipython-input-24-1453b78e0d58>:17: FutureWarning: to_gbq is deprecated and will be removed in a future version. Please use pandas_gbq.to_gbq instead: https://pandas-gbq.readthedocs.io/en/latest/api.html#pandas_gbq.to_gbq
#   km.to_gbq(table_id, project_id=project_id, if_exists='replace')
# 100%|██████████| 1/1 [00:00<00:00, 1817.29it/s]

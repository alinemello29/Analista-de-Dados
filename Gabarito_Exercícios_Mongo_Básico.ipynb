# %%
import pandas as pd

# %%
# !pip install pymongo
# Out:
# Collecting pymongo
#   Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (22 kB)
# Collecting dnspython<3.0.0,>=1.16.0 (from pymongo)
#   Downloading dnspython-2.7.0-py3-none-any.whl.metadata (5.8 kB)
# Downloading pymongo-4.10.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.5 MB/s eta 0:00:00
# Downloading dnspython-2.7.0-py3-none-any.whl (313 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 313.6/313.6 kB 15.3 MB/s eta 0:00:00
# Installing collected packages: dnspython, pymongo
# Successfully installed dnspython-2.7.0 pymongo-4.10.1

# %%
from pymongo import MongoClient

# %%
# !curl ipecho.net/plain
# Out:
# 35.196.228.235

# %%
fornecedor = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRvp1cZrRBs8Pkn45x43QITG4VdBmaHIACf1hoA9JVGOAn-VPK_YQpV7X9X4qMJldbBE9RDxoNEXAUu/pub?gid=1370589180&single=true&output=csv')
fornecedor.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 630 entries, 0 to 629
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id Fornecedor  630 non-null    int64
#  1   Razao Social   630 non-null    object
#  2   Nome Fantasia  630 non-null    object
#  3   Tipo Pessoa    630 non-null    object
#  4   Municipio      630 non-null    object
#  5   UF             630 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 29.7+ KB

# %%
recebimento = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vRlWoWQQKZ6jY1WlP3wsORM2_TK4r7x10RZIzhDbaFHuM1-v4nQtrhtM6NPCJNqXrkM1rJzC1XWQU49/pub?gid=887958935&single=true&output=csv')
recebimento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1721 entries, 0 to 1720
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id Cliente             1721 non-null   int64
#  1   Id Conta Bancária      1721 non-null   object
#  2   Data de Emissao        1721 non-null   object
#  3   Data de Vencimento     1721 non-null   object
#  4   Data da Movimentação   1721 non-null   object
#  5   Valor da Movimentação  1721 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 80.8+ KB

# %%
cliente = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vQz4t99vzQbPSO5bMuYYos2yUxjiJAittk1DbUF6dfjh9SQPvOqsAsK0vzSde163WlhvP9sSpy9jWZr/pub?gid=1762561321&single=true&output=csv')
cliente.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 812 entries, 0 to 811
# Data columns (total 6 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Id Cliente     812 non-null    int64
#  1   Razao Social   812 non-null    object
#  2   Nome Fantasia  812 non-null    object
#  3   Tipo Pessoa    812 non-null    object
#  4   Municipio      812 non-null    object
#  5   UF             812 non-null    object
# dtypes: int64(1), object(5)
# memory usage: 38.2+ KB

# %%
pagamento = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSgimtgaXu_Az4aca3Uk9xXHPZx-isUbWVyijtm5Tg_NXZkuI3xgShdyz9KHqLQ2S9O0-smLS1qKN5i/pub?gid=985843317&single=true&output=csv')
pagamento.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1004 entries, 0 to 1003
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   Id Fornecedor          1004 non-null   int64
#  1   Id Conta Bancária      1004 non-null   object
#  2   Data de Emissao        1004 non-null   object
#  3   Data de Vencimento     1004 non-null   object
#  4   Data da Movimentação   1004 non-null   object
#  5   Valor da Movimentação  1004 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 47.2+ KB

# %%
banco = pd.read_csv('https://docs.google.com/spreadsheets/d/e/2PACX-1vSXpstJo_b9Trdg8iZhR388qnMRl1DcFkA131LcxePjSEPOzfjjNwg6NBu-yZ_Ji1KDbU8WtetPTFGl/pub?gid=1688656687&single=true&output=csv')
banco.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 24 entries, 0 to 23
# Data columns (total 5 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   Id Banco           24 non-null     int64
#  1   Id Conta Bancária  24 non-null     object
#  2   Nome Banco         24 non-null     object
#  3   Município          24 non-null     object
#  4   UF                 24 non-null     object
# dtypes: int64(1), object(4)
# memory usage: 1.1+ KB

# %%
# Conectar ao MongoDB Atlas
client = MongoClient('mongodb+srv://douglasdealmeidaribeiro:c2ygnygvNLpGtOZr@cluster0.xu3hl.mongodb.net/?retryWrites=true&w=majority&appName=Cluster0')
db = client['financeiro']  # Nome do banco de dados

# %%
fornecedor = fornecedor.to_dict(orient='records') # transforma o df pandas em um dicionário python
db.fornecedor.insert_many(fornecedor)

# %%
recebimento = recebimento.to_dict(orient='records')
db.recebimento.insert_many(recebimento)

# %%
cliente = cliente.to_dict(orient='records')
db.cliente.insert_many(cliente)

# %%
pagamento = pagamento.to_dict(orient='records')
db.pagamento.insert_many(pagamento)

# %%
banco = banco.to_dict(orient='records')
db.banco.insert_many(banco)

# %%
'''
1 - Filtre os clientes de São Paulo e os exiba em um df pandas
'''
a = list(db.cliente.find({'Municipio':'SAO PAULO'}))
df = pd.DataFrame(a)
df.drop('_id',axis=1,inplace=True)
df.head()
# Out:
#    Id Cliente   Razao Social                          Nome Fantasia  \
# 0           1       00_VPCOM  VENTOS POTIGUARES COMERCIALIZADORA...
# 1           5  3 CORACOES AL           TRES CORACOES ALIMENTOS S.A.
# 2           8      3M MANAUS     3M MANAUS INDUSTRIA DE PRODUTOS...
# 3          10          3RIOS            3RIOS FIBRAS E RESINAS LTDA
# 4          11          43 SA                43 SA GRAFICA E EDITORA
#
#      Tipo Pessoa  Municipio         UF
# 0  Pessoa Física  SAO PAULO  SÃO PAULO
# 1  Pessoa Física  SAO PAULO  SÃO PAULO
# 2  Pessoa Física  SAO PAULO  SÃO PAULO
# 3  Pessoa Física  SAO PAULO  SÃO PAULO
# 4  Pessoa Física  SAO PAULO  SÃO PAULO

# %%
'''
1 - Filtre os clientes de São Paulo e os exiba em um df pandas
'''
a = list(db.cliente.find({'UF':'SÃO PAULO'}))
df = pd.DataFrame(a)
df.drop('_id',axis=1,inplace=True)
df.head()
# Out:
#    Id Cliente   Razao Social                          Nome Fantasia  \
# 0           1       00_VPCOM  VENTOS POTIGUARES COMERCIALIZADORA...
# 1           5  3 CORACOES AL           TRES CORACOES ALIMENTOS S.A.
# 2           8      3M MANAUS     3M MANAUS INDUSTRIA DE PRODUTOS...
# 3          10          3RIOS            3RIOS FIBRAS E RESINAS LTDA
# 4          11          43 SA                43 SA GRAFICA E EDITORA
#
#      Tipo Pessoa  Municipio         UF
# 0  Pessoa Física  SAO PAULO  SÃO PAULO
# 1  Pessoa Física  SAO PAULO  SÃO PAULO
# 2  Pessoa Física  SAO PAULO  SÃO PAULO
# 3  Pessoa Física  SAO PAULO  SÃO PAULO
# 4  Pessoa Física  SAO PAULO  SÃO PAULO

# %%
'''
2 - Faça uma consulta que retorne todos os fornecedores do tipo pessoa física
exiba em um df pandas
'''
fornecedores = list(db.fornecedor.find({'Tipo Pessoa':'Pessoa Física'}))
df = pd.DataFrame(fornecedores)
df.drop('_id',axis=1,inplace=True)
df.head()
# Out:
#    Id Fornecedor             Razao Social  \
# 0              3  AGROGEN DESENVOLVIMENTO
# 1              4           AGROINDUSTRIAL
# 2              5                AGROLEITE
# 3              6                AGROMAGGI
# 4              7              AGROMANTOVA
#
#                          Nome Fantasia    Tipo Pessoa       Municipio  \
# 0  AGROGEN DESENVOLVIMENTO GENETICO...  Pessoa Física  BELO HORIZONTE
# 1      AGROINDUSTRIAL SAO FRANCISCO...  Pessoa Física  RIO DE JANEIRO
# 2       AGROLEITE CABINAS AGRICOLAS...  Pessoa Física       SÃO PAULO
# 3              AGROPECUARIA MAGGI LTDA  Pessoa Física       SÃO PAULO
# 4                     AGROMANTOVA LTDA  Pessoa Física       SÃO PAULO
#
#                UF
# 0    MINAS GERAIS
# 1  RIO DE JANEIRO
# 2       SÃO PAULO
# 3       SÃO PAULO
# 4       SÃO PAULO

# %%
'''
3 - Faça uma consulta que retorne todos os recebimentos e os exiba em um
df pandas
'''
recebimentos = list(db.recebimento.find())
df = pd.DataFrame(recebimentos)
df.drop('_id',axis=1,inplace=True)
df.head()
# Out:
#    Id Cliente Id Conta Bancária Data de Emissao Data de Vencimento  \
# 0          53  x 10859524552-06        1/2/2018           1/2/2018
# 1         178  x 39315597929-00        1/4/2018           1/4/2018
# 2         178  x 41541621975-04        1/5/2018           1/5/2018
# 3         178  x 63718177635-06        1/6/2018           1/6/2018
# 4         178  x 80771218846-00        1/6/2018           1/6/2018
#
#   Data da Movimentação Valor da Movimentação
# 0             1/2/2018                675,87
# 1             1/4/2018             153538,56
# 2             1/5/2018              29823,06
# 3             1/6/2018              52492,86
# 4             1/6/2018              29336,04

# %%
'''
4 - Faça uma consulta que retorne todos os pagamentos e os exiba em um
df pandas
'''
pagamentos = list(db.pagamento.find())
df = pd.DataFrame(pagamentos)
df.drop('_id',axis=1,inplace=True)
df.head()
# Out:
#    Id Fornecedor Id Conta Bancária Data de Emissao Data de Vencimento  \
# 0              9  x 80771218846-00       1/11/2018          1/16/2018
# 1            150  x 75664985359-06       1/13/2018          1/16/2018
# 2            150  x 61586581630-06       1/13/2018          1/16/2018
# 3            150  x 10641176832-10       1/19/2018          1/23/2018
# 4            197  x 77167377617-02       1/30/2018          1/30/2018
#
#   Data da Movimentação Valor da Movimentação
# 0            1/11/2018              19540,71
# 1            1/18/2018              1577,625
# 2            1/19/2018               1431,08
# 3            1/19/2018              2060,765
# 4            1/30/2018               13182,4
